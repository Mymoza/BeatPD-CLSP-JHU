# %% [markdown]
# # BEAT-PD Challenge
#
# Challenge website : https://www.synapse.org/#!Synapse:syn20825169/wiki/596118
#
# Data information : https://www.synapse.org/#!Synapse:syn20825169/wiki/600405

# %% [markdown]
# ### Ideas/Doubts [Laureano]
#
# VAD like thing to remove unwanted data?
# modified MFCC?
# X,Y,Z = relative positions or acceleration?
#
# Imp: Predict per person. Maybe UBM like thing and adapt it

# %%
# Import required libraries

# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from IPython.display import HTML, display

# Imports for the high pass signal
from scipy.signal import butter, freqz, lfilter

# KFold
from sklearn.model_selection import KFold

# Import required modules
from sklearn.preprocessing import StandardScaler

import os.path

# %%
# Data paths

data_dir = "/home/sjoshi/codes/python/BeatPD/data/BeatPD/"
# FIXME : Move this to data?
path_save_accelerometer_plots = ("/home/sjoshi/codes/python/BeatPD/code/accelerometer_plots/")

# %%
def define_data_type(data_type):
    """
    Setup file names
    
    Keyword arguments:
    data_type = {cis , real}

    If data_type is real, data_real_subtype will have to be declared as well 
    data_real_subtype={smartphone_accelerometer, smartwatch_accelerometer, smartwatch_gyroscope}
    """
    if data_type == "cis":
        path_train_labels = (
            data_dir
            + data_type
            + "-pd.data_labels/"
            + data_type.upper()
            + "-PD_Training_Data_IDs_Labels.csv"
        )
        path_train_data = data_dir + data_type + "-pd.training_data/"

    if data_type == "real":
        path_train_labels = (
            data_dir
            + data_type
            + "-pd.data_labels/"
            + data_type.upper()
            + "-PD_Training_Data_IDs_Labels.csv"
        )
        path_train_data = (
            data_dir + data_type + "-pd.training_data/" + data_real_subtype + "/"
        )

    # Display labels
    df_train_label = pd.read_csv(path_train_labels)
    return path_train_data, df_train_label

# %%
def get_plot_title(idx, df_train_label):
    """
    Create a title that identifies the plotted graph with the measurement_id, 
    subject_id, on_off label, dyskinesia and tremor labels.
    
    Keyword arguments:
    - idx: 
    - df_train_label: DataFrame containing the following columns 
            [measurement_id, subject_id, on_off, tremor, dyskenisia]
    
    Returns: A string concatenating all the values mentioned 
    """
    # Following val_* variables are only used to format a cute title for the charts
    val_subject_id = df_train_label.loc[[idx]]["subject_id"].values[0]
    val_on_off = df_train_label.loc[[idx]]["on_off"].values[0]
    val_dyskinesia = df_train_label.loc[[idx]]["dyskinesia"].values[0]
    val_tremor = df_train_label.loc[[idx]]["tremor"].values[0]
    return "{0} = on_off: {1}, dyskinesia: {2}, tremor: {3}".format(
        val_subject_id, val_on_off, val_dyskinesia, val_tremor
    )

# %%
def plot_accelerometer(data_type, path_accelerometer_plots, path_inactivity=None):
    """
    Plots the accelerometer data. There will be 3 subplots for each axis (X, Y, Z)
    
    Keyword arguments: 
    - data_type={cis , real} : It depends on which database is used 
    - path_accelerometer_plots: Path where the accelerometer plots are going to be saved 
    - path_inactivity: Path where the dataframe with inactivity  removed are 
    """
    # Iterating through all the indexes contained in df_train_label
    for idx in df_train_label.index:
        if path_inactivity is None:
            df_train_data = pd.read_csv(
                path_train_data + df_train_label["measurement_id"][idx] + ".csv"
            )
        else:
            df_train_data = pd.read_csv(
                path_inactivity + df_train_label["measurement_id"][idx] + ".csv"
            )

        # FIXME: BUG ?  why the following goes to 1000xxx sometimes? It should be max 59xxx
        print("measurement_id : ", df_train_label["measurement_id"][idx])
        # Following val_* variables are only used to format a cute title for the charts
        great_title = get_plot_title(idx, df_train_label)

        # The time doesn't have the same name depending on the data_type
        x_axis_data_type = "t" if data_type == "real" else "Timestamp"

        # Normalize the data
        cols_to_norm = ["x", "y", "z"] if data_type == "real" else ["X", "Y", "Z"]
        df_train_data[cols_to_norm] = df_train_data[cols_to_norm].apply(
            lambda x: (x - x.min()) / (x.max() - x.min())
        )

        df_train_data.plot(
            x=x_axis_data_type, legend=True, subplots=True, title=great_title
        )

        # Save plotted graph with the measurement_id as name of the file
        plt.savefig(
            path_accelerometer_plots + df_train_label["measurement_id"][idx] + ".png"
        )
        plt.show()
        plt.clf()
        plt.cla()
        plt.close()

# %%
def prepro_missing_values(df_train_label):
    """
    Filling NaN values with -1. 
    
    Keyword arguments:
    - df_train_label: DataFrame containing the following columns 
            [measurement_id, subject_id, on_off, tremor, dyskenisia]
    """
    # Replace NaN values with -1.0 because otherwise plotting triggers an error
    df_train_label = df_train_label.fillna(value=-1.0)
    return df_train_label


def compute_symptoms_occurences_dataframe(df_train_label):
    """
    Computes how many times the symptoms are occuring for a single subject_id 
    
    Keyword arguments:
    - df_train_label: DataFrame containing the following columns 
            [measurement_id, subject_id, on_off, tremor, dyskenisia]
    """
    df_train_label = prepro_missing_values(df_train_label=df_train_label)

    # Group data by subject_id
    df_train_label_subject_id = df_train_label.groupby("subject_id")

    df_occurences = []
    symptoms = ["on_off", "dyskinesia", "tremor"]

    for key, value in df_train_label_subject_id:
        for symptom in symptoms:
            # Pour un patient, prendre les 3 dernieres colonnes, et pour 1 symptome, calculer le nb d'occurences
            counter = (
                df_train_label_subject_id.get_group(key)
                .iloc[:, -3:][symptom]
                .value_counts()
            )

            for symptom_value, symptom_occurence in counter.items():
                df_occurences.append(
                    (
                        {
                            "subject_id": key,
                            "symptom": symptom,
                            "symptom_value": symptom_value,
                            "occurence": symptom_occurence,
                        }
                    )
                )

    df_occurences = pd.DataFrame(
        df_occurences, columns=("subject_id", "symptom", "symptom_value", "occurence")
    )

    return df_occurences, df_train_label_subject_id

# %%
def plot_symptoms_occurences(df_occurences, df_train_label_subject_id):
    """
    This function plots the occurences of symptoms according to subject_id 

    Keyword Arguments: 
    - df_occurences: contains the df with occurences computed in compute_symptoms_occurences_dataframe
    - df_train_label_subject_id: contains df_train_label grouped by subject_id 
    """
    # There will be one graph plotted for each patient, for each of the 3 symptoms
    nb_subjects_id = (
        df_occurences.subject_id.nunique()
    )  # nb of unique patients in the label file
    print("Nb subject_id : ", nb_subjects_id)
    height = 30 if nb_subjects_id > 10 else 10
    fig, axes = plt.subplots(
        nrows=nb_subjects_id, ncols=3, figsize=(10, height), sharey=True
    )  # 3 cols for the 3 symptoms

    # Quick fix to plot the graphs at the right place. Starts at -1 because in the first for loop
    # it is incremented
    patient = -1

    # Plot for all subject_id 3 bar plots for all the symptoms and their occurences
    # Reminder that NaN values (missing values) were replaced with -1 and are shown as such in the plots
    symptoms = ["on_off", "dyskinesia", "tremor"]
    for key, value in df_train_label_subject_id:
        patient = patient + 1  # value used to position the plots (row)
        symptom_no = 0  # value only used to position the plots (col)
        for symptom in symptoms:
            subject_symptom = " ".join(
                [str(key), symptom]
            )  # variable used to create a title for each plot
            df_train_label_subject_id.get_group(key)[symptom].value_counts().plot(
                kind="bar",
                x=symptom,
                title=subject_symptom,
                ax=axes[patient, symptom_no],
                sharey=True,
            )

            fig.tight_layout()
            plt.tight_layout()
            symptom_no = symptom_no + 1

# %%
def interesting_patients(df_train_label, list_measurement_id):
    """
    Filters df_train_label according to a list of measurement_id we are interested in analyzing

    Keyword Arguments:
    - df_train_label: Labels DataFrame containing the following columns 
            [measurement_id, subject_id, on_off, tremor, dyskenisia]
    - list_measurement_id: list of measurement_id 

    Returns:
    - df_train_label: filtered df_train_label containing only the measurements_id we are interested in 
    """
    filter_measurement_id = df_train_label.measurement_id.isin(list_measurement_id)

    df_train_label = df_train_label[filter_measurement_id]
    # display(df_train_label)
    return df_train_label

# %% [markdown]
# possible to have participant characteristics from additional db data? ex https://ieeexplore.ieee.org/abstract/document/7911257

# %% [markdown]
# ## WIP : Function to remove silence (inactivity)

# %%
def get_df_threshold(threshold_energy, max_values):
    """
    This function returns a dataframe of shape (3,1) containing what is the treshold for each X,Y,Z axis 
    depending on threshold_energy. 

    For example if threshold_energy=10, the function is going to return what is 10% of the max_values

    Arguments:
    - threshold_energy: Percentage of the max values we want to use as treshold 
    - max_values: Dataframe of the max values 
    """
    return (max_values * threshold_energy) / 100

# %% [markdown]
# ### Mean offset removal

# %%
def remove_inactivity_mean_offset(df_train_label):
    """
    Removal of inactivity segments detected with a threshold after the energy is centered over the mean
    This function is expected to be less efficient than removal of inactivity with the highpass threshold 
    
    Keyword arguments: 
    - df_train_label: DataFrame containing the following columns 
            [measurement_id, subject_id, on_off, tremor, dyskenisia]
    """
    for idx in df_train_label.index:
        df_train_data = pd.read_csv(
            path_train_data + df_train_label["measurement_id"][idx] + ".csv"
        )

        ### Following section works on removing offset with mean
        inputData_DCRemoved = df_train_data.iloc[:, -3:] - df_train_data.iloc[
            :, -3:
        ].mean(axis=0)

        # inputData with DC Removed only has NaN for the Timestamp values, so we are adding them
        inputData_DCRemoved.insert(0, "Timestamp", df_train_data["Timestamp"])

        # Plot the graph
        great_title = get_plot_title(idx, df_train_label)
        print(df_train_label["measurement_id"][idx])
        inputData_DCRemoved.plot(
            x="Timestamp", legend=True, subplots=True, title=great_title
        )

        ### Following section works on removing inactivity following a treshold
        # Get the absolute max values for X, Y, Z
        max_values = inputData_DCRemoved.iloc[:, -3:].abs().max()

        # Compute what is X% of that max
        df_treshold = get_df_threshold(10, max_values)

        df_candidates = inputData_DCRemoved[
            (inputData_DCRemoved.X.abs() <= df_treshold["X"])
            & (inputData_DCRemoved.Y.abs() <= df_treshold["Y"])
            & (inputData_DCRemoved.Z.abs() <= df_treshold["Z"])
        ]

        print("Candidates to be removed:")
        display(df_candidates)

        filter_df = inputData_DCRemoved[
            ~inputData_DCRemoved.isin(df_candidates)
        ].dropna(how="all")
        great_title = "filter_df for : " + great_title
        filter_df.plot(x="Timestamp", legend=True, subplots=True, title=great_title)

        # FIXME: This function is not done. As it's not the priority, i'm switching to work on highpass filter
        # It doesn't remove the identified candidates or save the 0/1 vector

# %% [markdown]
# ### High pass filter

# %%
# Source of the code about the highpass: https://gist.github.com/junzis/e06eca03747fc194e322
# A bit more explanation here: https://medium.com/analytics-vidhya/how-to-filter-noise-with-a-low-pass-filter-python-885223e5e9b7


def butter_highpass(cutoff, fs, order=5):
    nyq = 0.5 * fs
    normal_cutoff = cutoff / nyq
    b, a = butter(order, normal_cutoff, btype="high", analog=False)
    return b, a


def butter_highpass_filter(data, cutoff, fs, order=5):
    b, a = butter_highpass(cutoff, fs, order=order)
    y = lfilter(b, a, data)
    return y


def remove_inactivity_highpass(
    df_train_label,
    energy_threshold,
    duration_threshold,
    mask_path,
    plot_frequency_response=False,
    plot_accelerometer_after_removal=False,
):
    """
    Removes inactivity according to a high pass filter. It will only be applied to the measurement_id provided
    in the df_train_label variable. A first condition for a measurement to be removed at a certain timestamp
    is that first, the energy is less than the energy_treshold. After that, we identify candidates with a vector
    where 0 represents a timestamp we want to keep, and 1 represents timestamps we detected as below the minimum 
    energy threshold. 
    
    The second threshold, called duration_threshold, represents the condition that there must be a minimum 
    number of consecutives candidates to be removed befoer the candidates will be indeed removed and confirmed
    as inactivity. For example, we could decide to only remove sections that are at least 1 minute long of 
    inactivity detected.
    
    Keyword Arguments:
    - df_train_label: DataFrame containing the following columns 
            [measurement_id, subject_id, on_off, tremor, dyskenisia]
    - energy_threshold: what percentage of the max energy do we consider as inactivity?
        For example, 1 of the max is considered as inactivity
    - duration_threshold: how long do we want to have inactivity before we remove it? 
        For example 3000x0.02ms=1min of inactivity minimum before those candidates are removed
    - mask_path: Path where to save the mask 
    - plot_frequency_response: Optional. {True, False}. 
                               Flag to determine if we want to plot the frequency response or not
    -plot_accelerometer_after_removal: Optinal. {True, False}.
                                Flag to determine if we want to plot the accelerometer after the inactivity
                                is removed
    """
    # Filter requirements.
    order = 10
    fs = 50.0  # sample rate, Hz
    cutoff = 0.5  # 3.667  # desired cutoff frequency of the filter, Hz

    # Get the filter coefficients so we can check its frequency response.
    b, a = butter_highpass(cutoff, fs, order)

    # Load every training file for each "row of labels" we have loaded in df_train_label
    for idx in df_train_label.index:
        print('Working on ', df_train_label["measurement_id"][idx])
        # Load the training data
        df_train_data = pd.read_csv(path_train_data + df_train_label["measurement_id"][idx] + ".csv")

        # Set the time axis. It's not the same name for the two databases
        x_axis_data_type = "t" if data_type == "real" else "Timestamp"
        t = df_train_data[x_axis_data_type]

        # Filter the data
        X_filtered_data = butter_highpass_filter(df_train_data["X"], cutoff, fs, order)
        Y_filtered_data = butter_highpass_filter(df_train_data["Y"], cutoff, fs, order)
        Z_filtered_data = butter_highpass_filter(df_train_data["Z"], cutoff, fs, order)

        ### Following section works on removing inactivity following a treshold
        # Get the absolute max values for X, Y, Z
        # FIXME: This could be made better but I won't lose time on this now
        # Get in a Series format because that's what the threshold function is expecting
        max_values = pd.Series(np.array([
                    np.abs(X_filtered_data).max(),
                    np.abs(Y_filtered_data).max(),
                    np.abs(Z_filtered_data).max(),
                ]))

        # Get the threshold of the filtered data
        df_treshold = get_df_threshold(energy_threshold, max_values)

        # Get 0/1 candidates
        X_zeros = np.abs(X_filtered_data) <= df_treshold[0]
        Y_zeros = np.abs(Y_filtered_data) <= df_treshold[1]
        Z_zeros = np.abs(Z_filtered_data) <= df_treshold[2]

        # Change data from boolean to 0 and 1s (int)
        X_zeros = X_zeros.astype(int)
        Y_zeros = Y_zeros.astype(int)
        Z_zeros = Z_zeros.astype(int)
        # AND operand to identify candidates across all axis
        # FIXME: change name of variable bc it's not a df
        df_zeros = X_zeros & Y_zeros & Z_zeros


        # Check if it reaches the time treshold (like minimum 1 minute long to be removed)
        start = 0  # Start and end of the series of 1
        end = 0
        indices_list = []  # List of tuples
        howmany = 0  # How many groups we identified (not required, just nice metric)
        count = 0  # How many 1 in a row we found

        # Counts the number of 0s and 1s in the original data before we apply the threshold
#         unique, counts = np.unique(df_zeros, return_counts=True)
#         print(dict(zip(unique, counts)))

        # Change the candidates for removal (1) to 0 if there are not enough 1s in a row to reach the
        # threshold. For example there needs to be 3000 times 1s in a row for 1 minute of "inactivity"
        # to be removed
        for i in range(0, len(df_zeros)):
            if df_zeros[i] == 1:
                count = count + 1
            else:
                if count >= duration_threshold:
                    start = i - count
                    end = i - 1
                    indices_list.append((start, end))
                    howmany = howmany + 1
                    count = 0
                elif (
                    count >= 1
                ):  # if it doesn't reach the threshold, we change the 1 for 0 because we don't want to remove those
                    start = i - count
                    end = i
                    df_zeros[start:end] = [0] * (end - start)
                    count = 0

        #print("There are "+ str(howmany) + " groups identified as candidates to be removed")

        # Counts the number of 0s and 1s in the data after we applied the threshold
#         unique, counts = np.unique(df_zeros, return_counts=True)
#         print(dict(zip(unique, counts)))

        # Save 0/1 candidates to csv
        # I use 1-df_zeros to swap the 0s and 1s.
        # 1: we want to keep this measure
        # 0: detected as inactivity so we want to remove it
        # Previously, it was the opposite, as 1s were considered inactivity
        df_mask_highpass = pd.DataFrame(1 - df_zeros)
        df_mask_highpass.to_csv(
            mask_path + df_train_label["measurement_id"][idx] + ".csv",
            index=False,
            header=False,
        )

        # Plot the accelerometer with the removed sections
        # The [0] is used to get a pandas.Series instead of a DataFrame
        # We insert Timestamp again as it was removed for the filtering
        # BUG : Should I use df_train_data or the filtered high pass dataframe?
        if plot_accelerometer_after_removal:
            filtered_df = df_train_data.iloc[:, -3:].multiply(df_mask_highpass[0], axis=0)
            filtered_df.insert(0, x_axis_data_type, df_train_data[x_axis_data_type])
            great_title = get_plot_title(idx, df_train_label)
            filtered_df.plot(
                x=x_axis_data_type, legend=True, subplots=True, title=great_title
            )
            plt.show()
            plt.clf()
            plt.cla()
            plt.close()

        # Plot the frequency response, and plot both the original and filtered signals for X, Y and Z.
        if plot_frequency_response:
            # TODO: Make the graphs bigger
            w, h = freqz(b, a, worN=8000)
            plt.subplot(4, 1, 1)
            plt.plot(0.5 * fs * w / np.pi, np.abs(h), "b")
            plt.plot(cutoff, 0.5 * np.sqrt(2), "ko")
            plt.axvline(cutoff, color="k")
            plt.xlim(0, 0.5 * fs)
            plt.title("Highpass Filter Frequency Response")
            plt.xlabel("Frequency [Hz]")
            plt.grid()

            plt.subplot(4, 1, 2)
            plt.plot(t, df_train_data["X"], "b-", label="X")
            plt.plot(t, X_filtered_data, "g-", linewidth=2, label="filtered X")
            plt.legend()
            plt.grid()

            plt.subplot(4, 1, 3)
            plt.plot(t, df_train_data["Y"], "b-", label="Y")
            plt.plot(t, Y_filtered_data, "g-", linewidth=2, label="filtered Y")
            plt.legend()
            plt.grid()

            plt.subplot(4, 1, 4)
            plt.plot(t, df_train_data["Z"], "b-", label="Z")
            plt.plot(t, Z_filtered_data, "g-", linewidth=2, label="filtered Z")
            plt.legend()

            plt.xlabel("Time [sec]")
            plt.grid()

            plt.subplots_adjust(hspace=0.7)
            plt.show()

            plt.show()
            plt.clf()
            plt.cla()
            plt.close()

# %%
# # NOT DONE ?...
# def apply_mask(df_train_label, mask_path):
#     """
#     Apply a mask on the list of measurement_ids provided through df_train_label 
    
#     Keyword arguments:
#     - df_train_label: DataFrame containing the following columns 
#             [measurement_id, subject_id, on_off, tremor, dyskenisia]
#     """
#     # Load every training file for each "row of labels" we have loaded in df_train_label
#     for idx in df_train_label.index:
#         # Load the training data
#         df_train_data = pd.read_csv(path_train_data + df_train_label["measurement_id"][idx] + ".csv")
#         df_mask = pd.read_csv(mask_path + df_train_label["measurement_id"][idx] + ".csv")

#         # multiply df_train_data by mask so the values to be removed are at 0
#         #         np.multiply(df2.iloc[:,-3:],df_mask.iloc[:,-1:])
#         df_train_data.iloc[:, -3:] = np.multiply(df_train_data.iloc[:, -3:], df_mask[:, -1:])
        
#         #         display(df_train_data)
#         # Check if that makes me keep the timestamp column

#         # Drop the 0 values from the training DataFrame
#         df_train_data = df[(df.T != 0).any()]

# %%
def apply_mask(measurement_id, mask_path):
    """
    Apply a mask on the list of measurement_ids provided through df_train_label 
    
    Keyword arguments:
    - df_train_label: DataFrame containing the following columns 
            [measurement_id, subject_id, on_off, tremor, dyskenisia]
    """
    # Load the training data
    print('measurement_id ', measurement_id)
    df_train_data = pd.read_csv(path_train_data + measurement_id + ".csv")
    df_mask = pd.read_csv(mask_path + measurement_id + ".csv", header=None)

    # multiply df_train_data by mask so the values to be removed are at 0
    #         np.multiply(df2.iloc[:,-3:],df_mask.iloc[:,-1:])
    df_train_data.iloc[:, -3:] = np.multiply(df_train_data.iloc[:, -3:], df_mask)#[:, -1:])

    #         display(df_train_data)

    # Drop the 0 values from the training DataFrame
    df_train_data = df_train_data[(df_train_data.iloc[:, -3:].T != 0).any()]
    df_train_data.reset_index(drop=True, inplace=True)
    return df_train_data

# %% [markdown]
# ## Get velocity

# %%
def get_derivative_value(df_train_data_context, m):
    """
    TODO 
    
    Keyword arguments:
    - df_train_data_context: TODO
    - m: TODO 
    """
    # Dot Product is the sum of the point wise multiplications between a and m
    cij = np.dot(df_train_data_context, m)
    denum = np.dot(m, m)
    return cij / denum

# %%
def get_first_derivative(df_train_label, derivative_path, n_zero=3, padding=False, mask_path=None):
    """
    TODO 
    
    cis-pd.training_data.velocity_original_data: Original data, which means the inactivity is untouched 
    
    Keyword arguments:
    - df_train_label: TODO
    - derivative_path: TODO
    - n_zero: TODO
    - Padding: [False, True] 
      - If True, it will add a padding of [0,0,0] at the beginning and at the end of the training data
      - If False, it will just use the existing values of the training data to have a (7,) vector from the
        training data
    - mask_path: Optinal. If provided, it will apply the high pass mask on the training data 
    """
    # m is a vector. For n_zero, it will be [-3, -2, -1, 0, 1, 2, 3]
    m = np.linspace(-n_zero, n_zero, num=2 * n_zero + 1)

    for idx in df_train_label.index:
        if os.path.isfile(data_dir+derivative_path+ df_train_label["measurement_id"][idx]+ '.csv'):
            print ("File exist : ", idx)
            continue
        
        # Load the training data
        if mask_path is not None:
            df_train_data = apply_mask(df_train_label["measurement_id"][idx], mask_path)
        else: # Going to get the first derivative from the original data 
            df_train_data = pd.read_csv(path_train_data + df_train_label["measurement_id"][idx] + ".csv")
        
        df_velocity= []
#         df_velocity_X = []
#         df_velocity_Y = []
#         df_velocity_Z = []

        if padding:
            # Padding DataFrame to add 3 empty rows at the beginning and at the end of the training data
            df_padding = []

            # FIXME: This could probably be made faster but I won't lose time on this
            df_padding.insert(0, {"Timestamp": -1, "X": 0, "Y": 0, "Z": 0})
            df_padding.insert(0, {"Timestamp": -1, "X": 0, "Y": 0, "Z": 0})
            df_padding.insert(0, {"Timestamp": -1, "X": 0, "Y": 0, "Z": 0})

            df_train_data = pd.concat(
                [pd.DataFrame(df_padding), df_train_data], ignore_index=True
            )
            df_padding = pd.DataFrame({"Timestamp": [-1, -1, -1],
                                        "X": [0, 0, 0],
                                        "Y": [0, 0, 0],
                                        "Z": [0, 0, 0]})

            df_train_data_padding = df_train_data.append(df_padding, ignore_index=True)
        else:  # FIXME remove this it's just a quickfix because there is the option with or without padding
            # and the next loop has to be on the original dataframe withtout padding
            df_train_data_padding = df_train_data

        # BUG : This df_velocity contains 3 extra rows. I'm not sure where they come from 
        for row in df_train_data[["X", "Y", "Z"]].itertuples():
            end = row.Index + n_zero

            start = row.Index - n_zero

            # QUICKFIX to the padding and pointers issue 
            if start == -3:
                start = 0
                end = 6
            elif start == -2:
                start = 1
                end = 7
            elif start == -1:
                start = 2
                end = 8
            elif end > len(df_train_data) - 1 and not padding:
                end = len(df_train_data)
                start = len(df_train_data) - (2 * n_zero)
                      
            df_velocity.append([get_derivative_value(df_train_data_padding.loc[start:end, "X"], m),
                                 get_derivative_value(df_train_data_padding.loc[start:end, "Y"], m),
                                 get_derivative_value(df_train_data_padding.loc[start:end, "Z"], m)])
            
        # Build the DataFrame with all the columns together so we can save it to CSV
        df_velocity = pd.DataFrame(df_velocity, columns=['X','Y','Z'])

        df_velocity.to_csv(
            data_dir + derivative_path + df_train_label["measurement_id"][idx] + ".csv",
            index=False,
            header=["X_velocity", "Y_velocity", "Z_velocity"],
        )

# %%
def get_first_derivative(measurement_id, derivative_path, n_zero=3, padding=False, mask_path=None):
    """
    TODO 
    
    cis-pd.training_data.velocity_original_data: Original data, which means the inactivity is untouched 
    
    Keyword arguments:
    - df_train_label: TODO
    - derivative_path: TODO
    - n_zero: TODO
    - Padding: [False, True] 
      - If True, it will add a padding of [0,0,0] at the beginning and at the end of the training data
      - If False, it will just use the existing values of the training data to have a (7,) vector from the
        training data
    - mask_path: Optinal. If provided, it will apply the high pass mask on the training data 
    """
    # m is a vector. For n_zero, it will be [-3, -2, -1, 0, 1, 2, 3]
    m = np.linspace(-n_zero, n_zero, num=2 * n_zero + 1)

    file_path= data_dir+derivative_path+ measurement_id + '.csv'
    if os.path.isfile(file_path):
        print ("File exist : ", file_path)
        return

    # Load the training data
    if mask_path is not None:
        df_train_data = apply_mask(measurement_id, mask_path)
    else: # Going to get the first derivative from the original data 
        df_train_data = pd.read_csv(path_train_data + measurement_id + ".csv")

    df_velocity= []
#         df_velocity_X = []
#         df_velocity_Y = []
#         df_velocity_Z = []

    if padding:
        # Padding DataFrame to add 3 empty rows at the beginning and at the end of the training data
        df_padding = []

        # FIXME: This could probably be made faster but I won't lose time on this
        df_padding.insert(0, {"Timestamp": -1, "X": 0, "Y": 0, "Z": 0})
        df_padding.insert(0, {"Timestamp": -1, "X": 0, "Y": 0, "Z": 0})
        df_padding.insert(0, {"Timestamp": -1, "X": 0, "Y": 0, "Z": 0})

        df_train_data = pd.concat(
            [pd.DataFrame(df_padding), df_train_data], ignore_index=True
        )
        df_padding = pd.DataFrame({"Timestamp": [-1, -1, -1],
                                    "X": [0, 0, 0],
                                    "Y": [0, 0, 0],
                                    "Z": [0, 0, 0]})

        df_train_data_padding = df_train_data.append(df_padding, ignore_index=True)
    else:  # FIXME remove this it's just a quickfix because there is the option with or without padding
        # and the next loop has to be on the original dataframe withtout padding
        df_train_data_padding = df_train_data

    # BUG : This df_velocity contains 3 extra rows. I'm not sure where they come from 
    for row in df_train_data[["X", "Y", "Z"]].itertuples():
        end = row.Index + n_zero

        start = row.Index - n_zero

        # QUICKFIX to the padding and pointers issue 
        if start == -3:
            start = 0
            end = 6
        elif start == -2:
            start = 1
            end = 7
        elif start == -1:
            start = 2
            end = 8
        elif end > len(df_train_data) - 1 and not padding:
            end = len(df_train_data)
            start = len(df_train_data) - (2 * n_zero)

        df_velocity.append([get_derivative_value(df_train_data_padding.loc[start:end, "X"], m),
                             get_derivative_value(df_train_data_padding.loc[start:end, "Y"], m),
                             get_derivative_value(df_train_data_padding.loc[start:end, "Z"], m)])

    # Build the DataFrame with all the columns together so we can save it to CSV
    df_velocity = pd.DataFrame(df_velocity, columns=['X','Y','Z'])

    df_velocity.to_csv(
        data_dir + derivative_path + measurement_id + ".csv",
        index=False,
        header=["X_velocity", "Y_velocity", "Z_velocity"],
    )

# %%
# def get_first_derivative(df_train_label, derivative_path, n_zero=3, padding=False, mask_path=None):
#     """
#     TODO 
    
#     cis-pd.training_data.velocity_original_data: Original data, which means the inactivity is untouched 
    
#     Keyword arguments:
#     - df_train_label: TODO
#     - derivative_path: TODO
#     - n_zero: TODO
#     - Padding: [False, True] 
#       - If True, it will add a padding of [0,0,0] at the beginning and at the end of the training data
#       - If False, it will just use the existing values of the training data to have a (7,) vector from the
#         training data
#     - mask_path: Optinal. If provided, it will apply the high pass mask on the training data 
#     """
#     # m is a vector. For n_zero, it will be [-3, -2, -1, 0, 1, 2, 3]
#     m = np.linspace(-n_zero, n_zero, num=2 * n_zero + 1)

#     for idx in df_train_label.index:
#         # Load the training data
# #         FIXME : We want the data after it was filtered with the high pass
        
#         if mask_path is not None:
#             df_train_data = apply_mask(df_train_label["measurement_id"][idx], mask_path)
#         else: # Going to get the first derivative from the original data 
#             df_train_data = pd.read_csv(path_train_data + df_train_label["measurement_id"][idx] + ".csv")
        
#         df_velocity_X = []
#         df_velocity_Y = []
#         df_velocity_Z = []

#         if padding:
#             # Padding DataFrame to add 3 empty rows at the beginning and at the end of the training data
#             df_padding = []

#             # FIXME: This could probably be made faster but I won't lose time on this
#             df_padding.insert(0, {"Timestamp": -1, "X": 0, "Y": 0, "Z": 0})
#             df_padding.insert(0, {"Timestamp": -1, "X": 0, "Y": 0, "Z": 0})
#             df_padding.insert(0, {"Timestamp": -1, "X": 0, "Y": 0, "Z": 0})

#             df_train_data = pd.concat(
#                 [pd.DataFrame(df_padding), df_train_data], ignore_index=True
#             )
#             df_padding = pd.DataFrame({"Timestamp": [-1, -1, -1],
#                                         "X": [0, 0, 0],
#                                         "Y": [0, 0, 0],
#                                         "Z": [0, 0, 0]})

#             df_train_data_padding = df_train_data.append(df_padding, ignore_index=True)
#         else:  # FIXME remove this it's just a quickfix because there is the option with or without padding
#             # and the next loop has to be on the original dataframe withtout padding
#             df_train_data_padding = df_train_data

#         # BUG : This df_velocity contains 3 extra rows. I'm not sure where they come from 
#         for row in df_train_data[["X", "Y", "Z"]].itertuples():
#             end = row.Index + n_zero

#             start = row.Index - n_zero

#             # QUICKFIX to the padding and pointers issue 
#             if start == -3:
#                 start = 0
#                 end = 6
#             elif start == -2:
#                 start = 1
#                 end = 7
#             elif start == -1:
#                 start = 2
#                 end = 8
#             elif end > len(df_train_data) - 1 and not padding:
#                 end = len(df_train_data)
#                 start = len(df_train_data) - (2 * n_zero)
   
#             df_velocity_X.append(get_derivative_value(df_train_data_padding.loc[start:end, "X"], m))
#             df_velocity_Y.append(get_derivative_value(df_train_data_padding.loc[start:end, "Y"], m))
#             df_velocity_Z.append(get_derivative_value(df_train_data_padding.loc[start:end, "Z"], m))
# # df3 = pd.DataFrame([[2.3,1,2,3]], columns=['Timestamp','X','Y','Z'])
#         # Build the DataFrame with all the columns together so we can save it to CSV
#         df_velocity = pd.DataFrame({"X_velocity": df_velocity_X,
#                                     "Y_velocity": df_velocity_Y,
#                                     "Z_velocity": df_velocity_Z,})

#         df_velocity.to_csv(
#             data_dir + derivative_path + df_train_label["measurement_id"][idx] + ".csv",
#             index=False,
#             header=["X_velocity", "Y_velocity", "Z_velocity"],
#         )

# %%
data_type = "cis"

# TODO: explain
path_train_data, df_train_label = define_data_type(data_type=data_type)

#list_measurement_id=['2d852742-10a9-4c56-9f38-779f2cd66879']

# Filter df_train_label according to the measurement_id we are most interested in
#df_train_label = interesting_patients(df_train_label=df_train_label, list_measurement_id=list_measurement_id)

from concurrent.futures import ProcessPoolExecutor
from functools import partial

do_work = partial(
    get_first_derivative, 
    derivative_path="cis-pd.training_data.velocity_original_data/",
    padding=True, 
    mask_path='/home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.high_pass_mask/'
)

num_jobs = 8
with ProcessPoolExecutor(num_jobs) as ex:
    results = list(ex.map(do_work, df_train_label['measurement_id']))

# TODO Get first derivative of the data with high pass
#get_first_derivative(df_train_label, 
#                     #"cis-pd.training_data.velocity_original_data_test/", 
#                     "velocity_original_data_test/",
#                     padding=True, 
#                     mask_path='/home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.high_pass_mask/')

# n zero vector / k
# k = convolution of the whole signal with v
# dont have to separate the signal in chunks
# Out:
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/cc7b822c-e310-46f0-a8ea-98c95fdb67a1.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/0c579a72-bac5-46a2-8671-1a50620723bf.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/5163afe8-a6b0-4ea4-b2ba-9b4501dd5912.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/5cf68c8e-0b7a-4b73-ad4f-015c7a20fb5a.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/fb188ae2-2173-4137-9236-19a137a402c2.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/19a3e9ea-fce1-40b7-9457-2618970beb7b.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/e2973da8-1250-4a7c-98d5-b165570a8aeb.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/8548d34c-4771-4ca4-bee4-d47bde435bdc.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/bb59d008-25fe-43cc-bf05-6bd6b874eea3.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/4a1ca52c-2895-4094-bade-246fd474762f.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/f53cfd9b-8c52-4d22-a35c-504542170ed3.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/dc90dc36-b4e5-43ec-b3e8-47c39c763c71.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/e31db4f8-f9a5-4273-a874-4bdbc6fcae2c.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/d1a9294c-05ad-4eac-9915-7052c2ad98a3.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/cc0d147f-94ea-4637-91d7-d4ceceaf1728.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/20f1dbcd-0954-4bfd-ad92-9bac1b15beb0.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/c05991ea-ed30-45ee-96a2-8a44d6ac0916.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/3cf49c01-0499-4bad-9167-67691711204a.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/ac449a51-1819-4944-b5c3-ef42be404541.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/6110744d-3f5c-4f2e-9586-f2722352606f.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/8b7abdf9-5aad-4edc-9bc4-078e29f134d6.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/278a1441-2e3a-467d-81c5-143e0298454b.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/0b5f2f06-e73c-4838-9f4c-d68b909a9356.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/1a90e8a3-dd3f-440a-9161-7886737e9d87.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/68bf2103-4211-45e9-82d7-8b4e713b2e3b.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/e93b52ca-83af-46fb-baad-46c934ab4edf.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/610face1-43e9-4a7c-b1f2-20deba03d587.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/18cdf618-e263-4843-9640-f41ad8ff4bde.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/66a44bdc-b216-4be1-90aa-d5d05f64ba01.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/f59c374f-b39d-48d6-aef9-2f42ca3a67e4.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/979c5c53-30c7-4e9c-87f0-261ea0d79ffe.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/e630e9fd-6518-43c0-9312-3254bcf9a8a0.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/dde97977-d155-4f07-8a47-6a318bd530eb.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/9230106e-5dcf-4034-bd54-c016f49294d8.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/85fee6b9-b3d9-4506-833b-ce5ca3a8d94f.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/29103438-8d6c-41f8-a3b9-89fff8074b6a.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/73dee9e5-9bec-4dd2-967b-e1bd59b0629d.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/4b269cc2-8f0c-4816-adbf-10c0069b8833.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/f4728921-8a52-468b-b6af-523108a1285f.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/3444e818-0ee3-4a2b-953a-f4dbc43b5d13.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/f76830fe-e0b0-463a-9162-63b00478067e.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/c7312d73-cb34-4025-b8b8-5299b4033e2f.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/5f9347a1-bf84-48ee-b3cc-c357401780cf.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/9152519b-4b57-43be-963c-dd7218495001.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/7fa0d4ab-c159-4335-ad91-6dc3ec812686.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/11dfbcf2-cd03-4b10-83b4-ad428153b200.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/50fd9915-06d1-4871-9103-ed125ea75764.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/476d6522-cd73-43e9-81c6-66980c575453.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/4e996f6e-4979-4ffb-a017-112100675eed.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/ef4b3a31-2744-4bec-996f-5c1861478c30.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/e5f4f2d3-9842-462f-8b91-6ccaa6c30a33.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/631b2ad6-1b00-46f5-8d74-c0b47a2419f0.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/ef0da5f7-79e5-45bc-bd12-d70137054762.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/1c3dda9b-984c-43b2-9686-0316e2254393.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/b34c12f1-1927-4d6b-b936-d0328aed05a7.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/e49db734-9ccf-4581-ae15-cbda39262bbf.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/cf15d497-b4d7-4bd4-9ba4-ae3bf0ed38b7.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/12513701-85b5-4278-bd15-dafae072d599.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/c4babc3e-cf11-42c5-93e9-7c0ccb2f2507.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/a65ac7f5-e28d-4009-9cfb-05a06e8fa1a5.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/1e0f16d8-3303-4c39-930b-ab3fff2c55cc.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/0a439836-acf1-475b-a4dc-103e8fd5ecbc.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/c5f6bee5-4f02-4761-a848-d68f513e697e.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/32184eb0-2e4c-49a2-8d63-c1a67f9e17a3.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/6983d20c-94b3-4694-b1f1-06931c71ef1c.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/855cdaf2-e00a-402d-b76b-0a3a4a10ff84.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/63a65c00-7d4d-4ee2-909c-84cd2d50d805.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/184ffe2e-f6c6-414d-ae43-d01bcd5568d9.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/1e051b85-eca9-4831-b1e3-444a4cb18269.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/4d38808c-a2e2-40bf-9804-6cc0ad9b7383.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/8340ba3e-2a36-4bcc-bf6f-bfdc852538d0.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/49202934-d5f5-4e83-8c61-c04ed0ae4a35.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/7259459c-3242-474e-89ad-28c4bae46b87.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/74e7102c-8a25-43e5-8f23-f0cfb6a9a58f.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/adaecec4-fb45-4fcb-8056-8f5ab6116c49.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/a47b5b1d-34b1-40ae-b03e-d1c75e054d49.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/1d624788-41fd-4c7d-b2c3-2fed920457f6.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/9312d505-c3c9-4d2a-88ba-2ce1d3d451a8.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/a373e8f0-8c0f-4660-b4ba-ea87bea012fe.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/ff0e52c1-b449-4bb4-8465-e35535c1c667.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/0dfd3d96-7b99-4522-9bf5-c39046fcf096.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/f8946f25-022a-47ba-9868-69120c94b0f2.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/27c0e5f5-d68f-4c42-a327-1bce67d5d394.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/eed7c640-e9a9-4c1f-a5f2-36385c73b0ea.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/432acdf1-9802-4508-8a33-b75cee3636e7.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/ec3a340a-1ce0-42be-912d-6a537474facf.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/9d41900e-9a38-4a4c-9963-8fc6a54dd24c.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/3f638137-e1ef-4173-8d95-f1be574cc5c4.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/ef25ea20-65f6-4cf6-9065-6fddcbd8c165.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/932197a8-dca4-4a3e-8ea6-413369bbc08d.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/5022980a-ccea-452f-887a-c67b58c82c22.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/62b06ad2-44ce-4ff3-8738-0229dcfcf0f8.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/19139e4f-0281-4b8c-8fdf-16df5d9e6e11.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/35a66db9-732d-426c-8ff9-0fc3e8464eef.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/0ca76d3f-ef24-4b60-9dc1-d6d092c65f71.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/cc730391-146b-420f-9255-c3185061f178.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/daf11494-e6fa-4376-a78a-86c683885764.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/851c6c57-1bfc-4294-bdee-a29d8781d1cc.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/29457aec-ab0a-43e7-a1ea-d0ee2600b73a.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/ce244565-bd09-4e45-8af2-521c8bbe27ce.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/9168bde2-364f-4805-abcf-82908a2800c6.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/0514cc23-74af-4624-8f4b-33c92e98a2f6.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/5703c24d-5adb-45ae-a01d-c7ed2efec6ba.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/e99ca464-11dd-46ba-83db-af554d046aac.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/5d8b5847-e01f-43c6-bdea-f164ba581a22.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/00bbb4c4-bb9a-4c3a-9c1b-3bf5f079d336.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/437da5ec-c6e7-4151-91a1-29f46328b465.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/4a0e5d1b-9a28-4b17-8d41-37c24a0cc6ae.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/e6433883-51c5-4892-9a0f-6bb45824d03c.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/a6d798cd-fa82-4c9b-a109-42ef181c6630.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/9ddc336b-1c09-40ec-ba48-ca3872e9a8c8.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/0d348560-5e96-4066-83f5-bf7420d01141.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/3f14f15b-52c9-4e64-8067-10ae2ef949aa.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/28611db5-55a6-44c1-8a52-fe1ac200a2c0.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/eae51aee-8157-4e3e-bddf-c89562da438e.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/2a60e30a-1b88-43ab-8a0e-7d8cbd1daf82.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/76d625ac-2cf3-4ea6-bd80-65f2f3874355.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/1d19c55e-d460-430d-98ee-73ad4a6d8268.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/46d9dd72-5372-44e2-929c-52d13b9874b4.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/0fb89752-d513-4500-8753-d4d2fdc29907.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/5f8d4735-f48b-48c4-90fe-870c17e40a8f.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/d9d41941-df97-42db-be98-50fb4304b482.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/5effef31-2e59-4626-a1a9-612513cfedbd.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/9b1e4fe6-32ad-4b42-b8c0-3b368154763b.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/79f34b92-483d-45b9-82cc-5e7db0ed68c2.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/bea3e480-aa8d-4d0c-ab56-8620dca0415f.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/829f4bab-393a-4614-bc6f-8205314ce09d.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/121bc9e5-863b-4561-9aaf-18dc23bd1ff1.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/fbf4f6d0-fe7e-4629-8275-95234ead58a7.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/89455dd3-3345-4d6f-b0bf-fe0feeb59f9e.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/31a6ecd7-9941-44a2-9067-4c0b67eb89b6.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/a18f4894-3ba5-4606-86a9-83693e9763fd.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/28fbb634-2cc5-40ed-8d26-3bc1fa951f69.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/1a39d1bd-d1d1-4133-a3d2-678212729e2f.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/4bc51b90-bfce-4231-85e1-5de3b4bc0745.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/5a1ce6dd-45a1-4bae-9777-65ed867c44cd.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/2da0ddb6-8c82-4960-9a90-a16d5fba6742.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/8aecd65f-5fba-4374-8705-1cc2dd078182.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/e14ad8a5-6a4b-4aa7-806e-89c0761c85ae.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/26c87488-28d7-4f25-8a8d-a6363a09b92a.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/41440dba-2717-4c5e-b383-463888bd4a43.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/e7e0edaa-0b81-4087-8c14-eff58313218b.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/8230f859-9ac4-44f4-a2a1-6dfb05503b28.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/b33c911b-a09e-4937-8e17-fb242b0fa589.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/ce1b6de8-fa7f-4051-9549-391178456fd1.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/5c331966-4bc0-40e9-a414-0dca02af2a50.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/5e5fbd98-571d-4a64-86ce-59f695d24ce3.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/9dc1f406-5d99-492c-aba5-d5c3ed938755.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/472201aa-effc-42a8-8f2b-11024eb5e913.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/92a43430-c3b2-442e-8d60-688048bb2ea0.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/79aca45e-ed46-4a12-829c-f98464604fbd.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/dcd5955e-3e94-40f2-818b-eda0fd33a76d.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/996aa23a-15a7-48d9-b511-9ff5499595b7.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/6dc8e615-1807-4738-a131-e73e12fc3b42.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/4ca00b70-b929-4a75-a990-494b915aa88b.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/43b147ad-6eef-4d2d-83ea-bca3b1cd0a77.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/4b08e275-50ae-4e00-90da-b64c15ccfb49.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/96582310-7914-4c80-9caf-557e8ecc3297.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/b6eedea1-4bcb-4942-8a62-9026aedfa699.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/89bc35c8-23d6-419e-a0a5-f3597e9e4931.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/dacc9306-457f-4c0f-b901-7e38d1130ec5.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/987115e5-f14c-4590-9ef7-b14169c25c1c.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/623b9e4b-a86b-46df-8304-fb5000f01cd5.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/08048b02-e033-46f4-a74f-b108d0530c2e.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/3d0f965c-9d72-43d1-9369-1ea3acf963cc.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/4553b646-092b-4d8b-aee4-c4a074059541.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/622a3d54-f542-4f3f-8a31-df0bbfc929ad.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/f7b180d9-77ff-40c8-b718-28b12670c247.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/a235ba27-a9a5-4d9a-931c-554950de9105.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/2ece7820-359e-4e81-a624-9e8dace9a584.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/f946ec6a-74d3-4297-a3a4-b165f2d72f13.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/5f2d1332-846c-48f6-a6ab-188d3737dcef.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/b0c7435a-5963-4ad4-a5e4-b0e17d5223cf.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/fb394080-2cba-454c-ad45-120fed0086e6.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/13239e7a-1c09-4bfe-a041-d739da36dff1.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/aee216fc-15d6-42ee-8e91-c8db3b16f0f6.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/1e5738bf-e918-4025-9d84-8df71e8d4810.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/0159954c-1bd2-47a6-9e6f-94f8d179b712.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/3b0ee95f-d87b-4699-b34f-74e7dc20ab01.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/c722ebb1-d798-41ae-adeb-b4a57bd41172.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/6867bf10-f489-4c7f-abd1-06a47dd2cdd9.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/b467614e-a297-4780-aec5-003fa5e8416f.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/b6f6ea11-7815-4c26-b8b0-1ce444327b5a.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/6fc11b99-5d79-4c68-a400-4327721b1025.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/02389c9e-8821-4c54-a1a7-912f0b66dd95.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/2d852742-10a9-4c56-9f38-779f2cd66879.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/9ac46426-d5f0-4a5b-9c18-90fe544973d7.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/1f260e98-4e0b-4bce-ae4b-f09129a279ef.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/233838f8-c430-429e-82e9-5b41a55ae86d.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/33ec24ca-a4d0-48a1-8f1a-282ad9b4f084.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/95d7b4b3-5b3c-47d2-aff2-05fce6a2cc56.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/6b70e1d7-e2a1-4a29-8ba9-841f7aee3d25.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/8b756127-e00b-433e-a86c-60d90c8de809.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/ff5e4e8f-dace-4913-9ea9-e7f4f80a9233.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/16223cff-4a1b-427c-b635-4b7ff0100c8f.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/226829d3-f889-460a-95bb-3835db5c83fa.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/58e358f6-ae96-4c29-8178-e82278263af4.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/5b540079-abd3-444a-ad9e-45267afa026d.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/b1fac9c3-5f9c-4464-8ad4-152a63eb4f48.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/b0eabbe3-e7f0-4677-85f7-107ca84ab9a0.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/178e8ab6-fa12-45d6-bc3b-f1ce7ccf6a77.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/78f9c3a3-64a3-4b8c-b8b2-1a91c84ed995.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/9a44ee78-2408-4116-bcc8-533a0a6708e6.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/ccf7e0e7-a3fc-48fb-88ce-529d2c882f22.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/3ed7e465-d3fb-4673-89cb-a78f23f0b887.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/79ca56ea-6538-4808-a163-6a1ddb562879.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/a0b9a464-b1a9-42b9-ad60-6ba222179be3.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/520a3d56-2689-4036-84e9-059b4ebf9a89.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/ff404d2a-3896-4a6a-ae75-4b9d3c86cae3.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/b9356dbc-a3a7-4bdf-be2b-705e462f524e.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/8c39ee63-0fb7-4a56-a9a5-eda3a70069a5.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/4dacabef-fcc4-49c9-b994-325027e5df13.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/ca71e75c-c9aa-4d52-8570-6d9d4d405889.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/7d759341-68cd-4e7a-a47e-32031d85081d.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/4195f059-861b-4785-abcd-686696bb86ac.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/bc89cf9a-1070-46d0-a30c-e0fbf3b39345.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/990b26e9-1836-4c1b-af94-4964ddabd418.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/9e3fa515-6478-492c-8555-96a9400945e1.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/eea9aca1-77da-4990-b8fa-7065902c7f58.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/3839d639-5418-4696-905f-56e28bc4b523.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/7ae4f371-e804-4d36-9e90-b10edf30d1c8.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/9cd72be6-3f5d-4dea-8949-e7ad74d7e8ef.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/b7d6c320-9ba8-46c1-a85d-9750478c157d.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/a881b1f9-c117-4702-89e8-4581ea76f66b.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/69bc1257-4d33-4b3a-8dae-475c9bf23852.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/2cd7708b-4b7a-4b14-8417-541956167342.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/8ec48f56-7807-4636-b697-173e0deee6a4.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/4e2f8120-10c0-4813-afa0-b1af71a01f11.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/154f44c3-d5bb-4179-af2b-41075cc67492.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/86545220-c044-4eb6-baa7-7d74152e0634.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/9ee5a9d6-29b4-457d-96a8-2685ef263c9e.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/2031b796-ee5e-4516-840a-b439d9d4088d.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/fafaa28b-fb4c-481b-b33d-ce7dfdd04c63.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/66b8e105-c0d3-4cb0-a0b9-36543547c49d.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/a00d94a9-c6dd-4847-9d03-f5ee06cbfe8e.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/ff3602fe-711e-48e7-a4c5-d1d9432caa4c.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/701b7765-59f1-4cd0-a7c7-3e8f3f6ddbea.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/48a4a73e-a77c-4876-ab26-19bc6eaa1005.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/342556fc-2043-4247-b564-d6a8d1becdf6.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/27e74c69-855c-4cee-8f77-80312e2eefb9.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/c549935b-49cd-446c-93a7-794377d5c7f4.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/99e984d3-c67e-4ab3-8540-ecabee635fdc.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/c7b82d35-63a8-429f-a038-cc6c7b5e6f4a.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/8739535b-de18-4189-b458-dc906ea1eac4.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/dd43a092-65bb-4c24-853a-9c0770da4a6c.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/283085d2-f25c-47c1-a568-d1d045ac9e38.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/8a0c1b07-9b03-4091-b484-3f47f5c644a9.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/8e12e211-5ec8-4ff1-bdee-10ce82afb4dd.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/deaef85d-7d3b-4382-b2b2-dee755b94592.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/fd1c988b-3928-4b8c-8f77-40311b49643f.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/7d0482b4-d768-4e37-9375-5a3a95bcd7ed.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/72fb058d-56ec-4b85-bcd7-4f8a0894570d.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/dd2b95c0-3b9e-4644-9870-d696f24f0582.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/15f8ae14-42de-4726-977c-1227bac332a9.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/2a91e324-0a19-48ad-972a-592bdb4cc50e.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/97f693e8-3b15-4207-93e8-54cee43b243f.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/61ffc084-9e6e-49f2-b235-8c6cf1bc2bae.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/759df848-e067-459f-be65-61fef277d75e.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/645eda3d-3e16-4c64-8599-327136bab767.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/e774603c-5a3c-4f72-8095-4a2162da6538.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/4a557eb6-6cac-4408-93f5-f8c35a8e8cd0.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/93c3ac1b-777f-4c64-9e2a-b2c3528e2110.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/0d1076d0-6bb0-4914-a7bc-855cbd272ad3.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/53e173dd-3ceb-40ed-bdcc-ac08a31b48ce.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/4fc3c295-857f-4920-8fa5-f21bfdc7ab4f.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/2a72fb3e-89a1-41cc-a2bd-c8d110fd4b2d.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/cbeefe93-b74d-4753-bf0d-eb464ff33d63.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/dfac884e-4363-4c16-ad1e-fcdc3faf8a3e.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/ecbb1910-d235-4692-a389-096187cf0b5c.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/03fd95e1-6d36-4a1e-942b-d9adeb2750e5.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/c97b5a40-5f28-491b-a12b-e7e30fd4cd79.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/14aaada9-e4cb-47c1-92ef-4059f2201d6f.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/a8c97fec-2adb-44c6-a7c0-c3f4078d2b49.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/55e8446f-07fe-4bc3-aa59-e736d2955dcd.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/017b6193-e0b7-4fb9-8312-97db38f8fb28.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/d96c3ffb-5d16-482e-bd9b-91b26aa87033.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/2e3a4c9c-ff01-4a28-bfcf-ce9b7633a39d.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/76df3a6c-62f3-4b04-a61e-0783aab179c6.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/3b8b01bf-6995-4f3b-acd6-b6f416cf1a49.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/da03a34a-5e53-48d1-8d30-2e477154bc38.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/675fe53a-74be-4bf9-966f-b4aa29ca1875.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/b8c1673b-a831-4055-9747-04128ed6aa20.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/0d1e04c5-c663-467b-b13e-fa66ba0b123f.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/dc5bdffc-9632-49f8-b0a4-66ade3fa2e33.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/ecdcfdb7-adb0-4cac-b790-cc692134cab0.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/e75a743d-188a-42cd-a0f4-72a9bbafe73d.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/131cb7c4-3df4-4cc8-bfcd-a93ef5a6c29b.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/d9e4b47b-5eb6-4887-a39e-4d1ab8be5ff6.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/c24d5930-a277-4780-951d-5cc26ec4ce5a.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/c2e2b686-6edc-4137-a851-27f0189c6990.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/55e5c67f-bae7-4a70-b65c-64995e1bf606.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/1152d443-ea4d-467e-beca-d8a26675aaee.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/94f30da8-525c-4a2a-93ba-044b0e99ff0d.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/ee24c57c-88f7-4f96-a063-05522913449e.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/da8bad50-109e-471e-a1d7-768b30745bd4.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/a90bb304-e913-4134-b03b-ec753d746513.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/1d065c00-51a4-434e-8864-17af7d6383b0.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/0e1a425d-4c98-4d5c-9c7a-65af5c3c9a85.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/2c93a5ce-8a5f-467b-9c0a-28b5c957c1c4.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/ad20b937-6cbd-433b-8fc3-6a1a9ceb2372.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/8c22c463-ee4a-4a07-85f3-aca9ac888c7e.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/8866665e-023c-4797-bd26-96de926de488.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/cf7858e0-1049-42ed-b0ab-4df011357a72.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/41efbb2d-899e-41f8-8c4b-144dfab08517.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/c1f866ae-b8d6-4f9a-abbc-07e2a264e562.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/bc495ea1-cb98-463a-8c0e-0f5feccfa81a.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/1cc72a5b-5cd0-482e-91ee-365c1d118790.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/8e967260-4fa4-4406-bb28-90f41feae786.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/5bdece70-2806-4e58-8bf6-0141c3cb71c7.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/aa689eaf-d601-4ff3-881c-91d7c5e4d3b3.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/19868ae3-5beb-4a86-89c5-8eff71e352fb.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/321e0987-b8a7-4fe0-984f-638badab72dc.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/2f39717a-554c-44dc-ae9e-ff98d77c5943.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/a7173b98-b7e0-4756-b172-c681e7432302.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/39501c5a-1ff5-499f-93df-3bd4aa1e3d98.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/9d7dee51-3852-49f7-8fce-198fa4200b9b.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/589bea23-ae1a-4d8b-9da0-c44537850d12.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/0e0bf9aa-a296-4456-87b3-cc67a46c752f.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/7764c2f4-ae43-420e-8924-c1777281c514.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/f8bf28f8-224b-474e-afe4-7a5392e11c87.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/df088ad5-4ab2-43c2-b9a2-7f7c09784f8e.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/08d3e583-587e-4616-8144-f4f847ef29b7.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/fc3a9f83-3022-4bad-9e86-3055fa467a1d.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/7bb248d3-765f-4a64-bdb9-c3f1f5150bb9.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/9a46cc72-41b9-4549-90bb-36a79e406447.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/f5b7c267-9bcb-4575-bc93-66f74fe6bdf7.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/ee5a0967-a645-49b4-a70b-842c5985ce52.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/3859007f-8d21-4d12-b294-9b69672cb687.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/7af335f3-dea0-4c8d-a143-04ec6da85343.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/72c9db1e-9ea4-454e-b381-3f8c83720b7d.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/8095fb1f-e406-4348-b405-c4479c87ad6d.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/35cdd5f6-afa5-4261-b9b6-0ebe5d4ac793.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/05a3b9dd-bbe4-4c4d-8571-1c692640aead.csv
# ...
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/aab4c3d4-0667-494a-b219-68e3bdf30a0f.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/078387ec-a6ed-4371-a53d-9e2fd8ab0246.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/d957e8cb-ab89-4953-a99c-7abd3776f410.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/591d6b1a-58df-4f91-be4c-cf839f4e5ea7.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/ac0b319d-2a01-4ad9-a955-246bf91abae6.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/f7ee9347-653b-44bb-948e-e8bf59404041.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/768199bc-115c-4bdd-b54f-6c97793be5de.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/dbd8a1f6-88a7-4dfc-a492-fe6d16e05d66.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/14558d53-1c97-42e7-a44d-119fa43fb145.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/ad5875fc-c06c-4490-abfd-0edbd1233060.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/40738aea-95b9-47f9-be0c-cbd880a312a9.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/b335ddd6-e718-41eb-a039-ce68802e7d13.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/8fefded5-b48a-4699-970b-0e8a259d7250.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/b82305c1-cf70-49b9-a840-753efadbf5be.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/709fb536-7683-4208-be74-6f485d20566a.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/edd8d5cb-60f7-4bec-85f5-f77ee4030f72.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/a438cc4c-bb38-496c-85cf-7369aeb06ed8.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/64cf6c13-7486-4c5b-892c-3249855dd371.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/d153d24c-dfa4-4a85-9142-7181b3a054d6.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/1ff4813f-2767-4fe4-8550-3f71e92d47ad.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/45ab928b-8e5c-465c-a884-17b56b29e428.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/f58a8090-a9d5-442e-ac54-bab549cda75d.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/e1052f8e-4bb3-4dc5-bd74-61283e3646ac.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/2b39005a-640d-4219-9b0b-6b6f9d579ce4.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/87d07e61-6d9c-448c-88d3-c4a12313aa4b.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/22b88456-fe8f-4138-af55-be12afca4b81.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/2edce234-12bc-42a9-a84c-33a27972dc7f.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/ad84583d-e5ae-4926-b077-531a0f7d08a9.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/3f35ab36-964d-4f27-a22c-ac063856d997.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/461d7ccc-f828-4646-94bf-755b2e67c652.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/279625c6-dd87-4747-96c9-3f8bd164e25e.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/b672bcc3-d0cf-48de-8a7a-6658f6105304.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/a2fcfa56-e0c7-4377-953a-432c8b2b8410.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/f1673644-c2b2-4ecb-a1ee-68e7bc6bac4f.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/1ab3f3ce-1be8-407f-a219-1bb55d753644.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/523a6364-527d-4bd8-bac4-8a2543b60620.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/fda59d04-0d73-4c26-be1d-10ea691cf9df.csv
# measurement_id  72d5e108-9228-46bc-b99f-309f4dc85c15
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/222fec69-7615-4d08-bad0-d47751014f14.csv
# File exist :  /home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.velocity_original_data/ae5c4a71-dd03-4c8e-b905-357b48d14f1e.csv
# measurement_id  edbbd001-ae29-4208-a7f0-cf088ac7db94
# measurement_id  0f5bc0ae-118b-4338-afd1-653fc5bbd3a3
# measurement_id  34a7e889-fffd-428f-9ed7-0814403507a9
# measurement_id  f59d2b7c-c6d2-4726-a244-f33a15c8f2d5
# measurement_id  08381404-b1b3-44f7-8e26-40a2183cfd28
# measurement_id  ceb52190-d81b-44d4-94cc-5823a918edfa
# measurement_id  858b51e0-1b31-4a93-8b8d-79d02b3606b7
# measurement_id  738e62aa-6552-4f8c-bee0-72fb96b7581e
# measurement_id  bbadb13c-ea0e-44e8-8908-cb1a18eebf40
# measurement_id  f28c38d1-cedf-4bd3-b488-bca6a64bb512
# measurement_id  50cd6ad2-9998-4dd7-83e7-ddb7da528256
# measurement_id  7027ed4d-9c95-4bf5-9aeb-d8f69a9821cf
# measurement_id  88662a33-82ec-40a4-a2fc-332cff45c5af
# measurement_id  83fd5aa0-e585-4200-b90c-60bb443cb2c4
# measurement_id  585f9628-039a-47af-adbc-d722b717a60a
# measurement_id  c1dda61b-9287-4e41-9742-fea19250bf2e
# measurement_id  005685b2-3de4-469b-b673-8f937ee8196e
# measurement_id  3e06f01c-a386-40c0-b452-50921b8f4e8a
# measurement_id  1c3b72c7-24d5-427c-9400-be1554688a4a
# measurement_id  f6fde688-844b-4c4c-8c5b-2c1709e265bd
# measurement_id  d7f747bf-1abd-4149-abb1-429bc99d8de7
# measurement_id  43c6a806-e912-43f7-aa5b-1091d398a836
# measurement_id  2c6285cf-8c39-431a-9db3-522f2c74fb4b
# measurement_id  c3bc0e8b-af62-4408-8e9b-f11b7e5f7672
# measurement_id  12f25bd0-efbc-4c38-9d72-62092f6a1e2d
# measurement_id  3adb3a14-f1f2-4a5b-be8e-8721c2f2e300
# measurement_id  4edfac00-9775-4bec-b50f-64505787d372
# measurement_id  773ca417-4e48-4088-a384-b0e72a2c3f84
# measurement_id  ed101b34-10e7-4331-a9ce-c8f1f5d99ef0
# measurement_id  b22b56ae-1963-4374-9588-002ef43e7d45
# measurement_id  1c2c091a-17ee-444e-96ce-edda2150927e
# measurement_id  a37efcfc-6d2f-457c-9778-b54e0ca5fd81
# measurement_id  92547cf5-442a-4248-95e7-ffe4ebd95b36
# measurement_id  cc66c552-e745-48fb-9d6b-3c6a31ea6b43
# measurement_id  7048cd06-b5c8-40ce-be89-dce7fa9a5822
# measurement_id  a03e1c8b-3849-4eb6-8a23-56454cd96ff5
# measurement_id  7b647bf1-ad2d-4bcf-a778-fb108e96c15e
# measurement_id  8c3bcb41-89ba-49e7-8f68-5dcb6b7993b2
# measurement_id  702952c7-85d1-475a-8bf1-4ed7c06e4448
# measurement_id  8c57a8b5-b295-4673-b8e2-9226a44715dd
# measurement_id  bdb10247-275c-46cf-a513-509c6e2f8845
# measurement_id  5cfb0ba5-266f-43e1-a0e9-ad07c7969e65
# measurement_id  5dd16d0a-b0b6-4ac8-b07e-e4e1b371499a
# measurement_id  fdb83fa0-278b-4aa1-a098-f62b5ddafc4d
# measurement_id  0f1690c1-0a60-4cf4-879a-88ba9e276edb
# measurement_id  866e3b29-28e3-43a4-a641-1be03660cb02
# measurement_id  a6f657be-0c54-4625-a409-d460d5766a84
# measurement_id  912a36fb-c8e8-45d7-93a5-5012b9b7ef08
# measurement_id  e5d0a383-6a91-4e3a-827a-79c5428d2e0c
# measurement_id  80549b84-4bb7-4cfb-a8f9-9b00dafe2676
# measurement_id  9efbbbe9-3746-4ca7-a167-796fe2cfa9d2
# measurement_id  e2db1f3c-52c6-40f5-bbaf-a540d1269834
# measurement_id  19488fae-0be6-479c-aef6-f26a7198bfd4
# measurement_id  4a885930-240d-4091-8717-e2c993e09632
# measurement_id  6783ee73-8486-473b-a66d-cc401f563c64
# measurement_id  4682ca4b-b812-444a-abf1-8a23ab0dd930
# measurement_id  c8d819fb-46da-4a09-ac4e-3b4648909fbb
# measurement_id  55b8fa1c-20d4-42a5-b4e1-0bdc02360b8b
# measurement_id  133f49e6-a1e3-454a-b622-62bcd1717ae2
# measurement_id  463f5b07-8021-44dc-ae23-13a8e664de5a
# measurement_id  5293138f-343f-4500-9fcf-1ef39e314085
# measurement_id  8f90f2e4-76fd-453f-bdd0-c36f13e5dc39
# measurement_id  dffcf070-5b39-4c57-ba0e-f8f0c6d3104c
# measurement_id  9a99e399-7a00-415a-918b-61c8e5ea898d
# measurement_id  88b45ad6-843c-4b43-b344-72a6f320405f
# measurement_id  ce1439a6-d9c7-4193-a42b-c5aaeaff5bc8
# measurement_id  26f37778-1761-4430-a8d8-b77146c84870
# measurement_id  72d310a2-7454-4168-8967-ffe77b0bb2f8
# measurement_id  3bfa721b-78f2-435f-8f59-3e6ebbe9ba6b
# measurement_id  cac4b3f5-d2c0-4b69-a347-389a59402991
# measurement_id  d93c29cd-5998-42b5-ab9c-4dfb206a9e2d
# measurement_id  830778c7-a167-4bf0-9474-8a774078be18
# measurement_id  18f37c81-c54f-4893-8418-66d438bea0d3
# measurement_id  d1f59637-5a3c-47fa-8d75-521ff326849c
# measurement_id  f45d68f6-fd53-4ed7-8368-be2a599a0c26
# measurement_id  4b711fed-ae5e-4ae0-b042-0669bda57955
# measurement_id  290d637e-bdd2-4ebd-a9e9-9f17a2c81eef
# measurement_id  21159c23-a2be-4abe-b78f-782640bb81f8
# measurement_id  bda67673-bda9-4b03-8f33-554f1b03ad3e
# measurement_id  261d7352-e171-4b2d-a321-9ed169d32b52
# measurement_id  cc7044d8-99c8-410a-b744-003705f74a04
# measurement_id  0d4896e3-d3bf-4557-bb7b-234efa673e2e
# measurement_id  44dd0ac6-6db3-46a4-9204-683896e69020
# measurement_id  9ca908e8-eb3f-45cc-ba3d-1e0ece544d9e
# measurement_id  4d2f8946-357b-465d-a511-99ce4e8fa209
# measurement_id  07f81047-9a4b-49fd-afc0-a985e2183411
# measurement_id  db5a84d2-286a-4d0a-ab63-ef46266b6dc4
# measurement_id  479ade9c-e30e-4968-8876-2efd6baa215f
# measurement_id  567467f1-3a9f-4f83-acc3-cfe85f8cead9
# measurement_id  c95093fd-5dcf-458a-96e6-77f64ffdb4c5
# measurement_id  1cf10288-36ba-4446-9468-4148ce759dd4
# measurement_id  94200403-2a6d-4485-b005-5f60457b2a49
# measurement_id  fdc7bf0b-5861-4868-b75e-52e5586364f3
# measurement_id  121e09e2-4089-4446-95e9-25a5ded53c39
# measurement_id  4f1c7885-db4a-4ace-b7e2-2f42626efb0d
# measurement_id  d7c928dd-cb62-460e-95d1-0c49616af5e3
# measurement_id  065e13fd-31da-4b73-a81c-b47d05cadaee
# measurement_id  2395e978-78dd-4d1c-b400-abdd1d54a27e
# measurement_id  72145919-18a0-48e7-a991-4ccfca1c8631
# measurement_id  84dc0f01-f9f6-4bf9-ab48-247d9bab6a62
# measurement_id  450adea9-8eff-443d-a3ee-e609b16d4887
# measurement_id  e28a0cf0-12a3-4f76-b900-dbf397a10787
# measurement_id  24538e09-5980-4600-9ef5-9d954c368218
# measurement_id  88632ba1-25bb-4684-a919-f03af448041d
# measurement_id  47093534-52ca-41df-8115-72e3e6ed371f
# measurement_id  da3f8cf7-31a8-4ebf-8bde-bf6965034153
# measurement_id  7babfb7e-3fa1-4a62-8b34-56c7a6a489f8
# measurement_id  3e358e5a-4801-4963-a8d2-0a08c66c2744
# measurement_id  e327bc48-a229-4991-bf65-9cd07f63164c
# measurement_id  25fc2ae4-6c0a-4e97-97b9-8debd4cf3a32
# measurement_id  cc8a2fff-2043-4e5a-b21f-58da4347bb22
# measurement_id  23d46fe9-848a-4547-ab2a-f17f88647c56
# measurement_id  52fefbd6-f774-418f-a021-37dac2960762
# measurement_id  540b902e-72cf-4554-8238-b1975a217c11
# measurement_id  26f5e58c-ab76-42e1-a252-43ed459a4ad7
# measurement_id  f05d6951-1dff-4333-ae49-ffe0158c3771
# measurement_id  9e716ef0-4644-43e5-9f79-bffd8332826b
# measurement_id  33ebd608-3fd6-423b-97cc-737bad622d98
# measurement_id  3daff34c-ee77-4f3e-9f87-df2d971a7112
# measurement_id  853834c0-4e12-4109-b45d-661086dbc15b
# measurement_id  7b62797c-9403-48e8-8b23-52708d05c963
# measurement_id  cf2a65d8-1f44-4e8d-b96c-1300935b1876
# measurement_id  b3719d0b-31bc-4190-915e-2e120c95ce2e
# measurement_id  504215b5-0c4a-481c-8d1e-1cb94d609ad1
# measurement_id  24eb7544-a3ef-4eea-9138-c381a43083c3
# measurement_id  7906f0f1-b1e3-44ab-b3d3-b81775766b81
# measurement_id  c54ee369-3f33-4ec0-a6d3-36f0a9b6e4ed
# measurement_id  ba1bb1b0-6170-4f6c-ac85-f62ebafcabb7
# measurement_id  54e54cfd-70fe-4555-a9a9-874f9d23e539
# measurement_id  389fd499-84df-4024-b9cd-a3f4502932f8
# measurement_id  0935d001-51cc-4165-ac2f-9cbb08943ea5
# measurement_id  b6af23cc-d71d-4860-902f-ebe18e34b6d1
# measurement_id  1c7702c0-6dfd-4508-ac30-6a9e0c3c93bb
# measurement_id  583c0294-e491-45c1-99fa-de7db66c621d
# measurement_id  52753b71-a77d-402a-90f6-4c3138cbcf29
# measurement_id  e7782276-6436-4c3b-b23e-ed934a101b30
# measurement_id  2c970298-cd63-45de-ac26-9570ec22f3a7
# measurement_id  5b4c9b1f-69ec-44db-92a2-d8c6a12628fd
# measurement_id  61c45fb9-df30-4566-b425-90601d9797f1
# measurement_id  6cee0eb6-78d4-4ead-bfc0-5c6eadee2232
# measurement_id  244d0ddd-5b91-4e47-b4e9-18f4ddca37d3
# measurement_id  651209d1-7280-4e7b-9c0e-0da94b3c9f49
# measurement_id  f0c0b302-62dc-4bd5-941f-16545c089a88
# measurement_id  9029c379-2e55-418d-b14d-7ad2d990e145
# measurement_id  cd8ff41b-fee3-4896-b841-ea40a757ff47
# measurement_id  bef2d1ff-fde4-40d8-a0e2-aea83035766f
# measurement_id  45eb4b5f-92c3-410e-8153-540fc9b0fb9a
# measurement_id  c7e9b24f-f42c-4e54-9647-c0e84a415a39
# measurement_id  9b4c5d9d-d3c1-4ddd-a879-ecdc06c6f2b0
# measurement_id  57c65032-0723-42c6-909b-0049bff15cb5
# measurement_id  43dd5795-ca7e-44f9-a31f-6879a6329f6c
# measurement_id  c5788cc6-3208-4fee-aa47-2a7b7c361d59
# measurement_id  abdb15f9-b1de-40d9-a7ec-b6849497cf3a
# measurement_id  6be90cb7-ce71-48f1-938d-04e6dfe6ed5a
# measurement_id  ee389c0c-71dd-47a9-9249-9c1bcd6c4f69
# measurement_id  eef56825-940a-4c3e-aebb-60838d60869e
# measurement_id  d17dc657-7704-4206-bce3-2ec1ff23b24b
# measurement_id  42f57b97-ed19-4306-bd6e-01b754301ab0
# measurement_id  7d869854-6b90-4ddc-adf7-b3f0496fe004
# measurement_id  963043f2-d998-4503-92a3-e00f18ff339b
# measurement_id  f91c78d8-c74a-4b48-8e6a-6a0638de3805
# measurement_id  c0136cdc-adc9-4945-8253-3be19ea908bf
# measurement_id  698d80f2-7653-4cce-a23b-035464f9ab83
# measurement_id  9c035149-7bba-409e-b31f-7d7627870873
# measurement_id  d4ad615e-a261-43f0-b4b9-ea35bc5bcd9b
# measurement_id  0d40cac9-665b-46ee-bb9a-d7f667513155
# measurement_id  db167612-4cd1-49c8-a4b3-118a4ad0c97c
# measurement_id  40f713fe-0ac9-4cd0-809c-0a8024955a2a
# measurement_id  4913062f-b696-40c6-a0f2-87efe1dd4810
# measurement_id  3ed5ad09-579c-48bb-b9ec-b14f44fa47f0
# measurement_id  3c79c86e-c792-46c0-98d0-55f3753017fc
# measurement_id  b9ada852-4ff5-4ee1-8529-96a79ced0610
# measurement_id  5f8103c5-120d-4736-8959-f368d74acb65
# measurement_id  abd3be20-bd13-49be-bd47-87821955bfb6
# measurement_id  88185aa3-3a84-40e4-a780-40a4cef198b4
# measurement_id  a38bf8c5-617d-4512-8c9e-70bc9195cc06
# measurement_id  b1b084cd-88ab-485d-af7e-e5a6e2c73c03
# measurement_id  1f57b4bc-bcd5-4d65-8a2c-7acfd94afaa2
# measurement_id  3cd93936-b55b-4b4c-9ea6-083db0729b20
# measurement_id  31956275-5c34-47ec-ba83-d5d107211af6
# measurement_id  7b2698a6-f3a5-4345-9630-25d377d58992
# measurement_id  22ba7c99-9274-41fd-9170-4364e00973a0
# measurement_id  8390b805-6091-4f12-8d03-a853c3405ddb
# measurement_id  7b9f5ce7-a152-4809-8930-c6bfaff0da8a
# measurement_id  dd261c90-aab6-40c3-9da7-1b8b320c7f7a
# measurement_id  fb86493b-1893-4be4-8707-1e97d56bb049
# measurement_id  dd140d80-bcab-458b-bd0e-82cd584d0f28
# measurement_id  e0441156-c4b8-467c-8f4f-3b532d594d8f
# measurement_id  e021c06a-263d-403b-ba89-71e1c345d042
# measurement_id  bead5c67-03dc-4bf6-8710-6130d64a1608
# measurement_id  f66cb02b-88b6-4dcd-bfda-391d506c69d8
# measurement_id  161c5ebc-8830-480c-a846-7213190f019a
# measurement_id  c46cfa20-9994-4dda-b258-17f1e0fd8fe3
# measurement_id  b0b10be2-e918-41c2-b031-b47ba56a2762

# %% [markdown]
# # CIS-PD Database

# %% [markdown]
# Contains 16 subject_id (patients) for the training set
#
# - Gender: 11 Male, 5 Female
# - Race: 15 White, 1 NA
# - Ethnicity: 15 Not Hispanic or Latino, 1 Unknown
# - Age average (standard deviation) : 62.8125 (10.8579)

# %%
data_type = "cis"

# TODO: explain
path_train_data, df_train_label = define_data_type(data_type=data_type)
# display(df_train_label)
# List of interesting measurement id we want to look at
# list_measurement_id=[#'ab5287f4-8261-47ad-8ff2-22b5fe5d246e',
#'db2e053a-0fb8-4206-891a-6f079fb14e3a']#,
# 'ef5b1267-c212-46c5-aab0-4f4437bc6c67',
# '4ec74fb9-7347-435d-83dc-79ad74c3bc49',
# '8e8539ad-8841-476b-b15c-888ce3461989',
# '22b88456-fe8f-4138-af55-be12afca4b81',
# 'ad84583d-e5ae-4926-b077-531a0f7d08a9',
# 'eef56825-940a-4c3e-aebb-60838d60869e',
# 'e0441156-c4b8-467c-8f4f-3b532d594d8f',
# '464ac314-6c4b-4c4a-957c-28a2339150d6']

list_measurement_id = [
    "5cf68c8e-0b7a-4b73-ad4f-015c7a20fb5a",
    "cc7b822c-e310-46f0-a8ea-98c95fdb67a1",
    "5163afe8-a6b0-4ea4-b2ba-9b4501dd5912",
    "db2e053a-0fb8-4206-891a-6f079fb14e3a",
    "2d852742-10a9-4c56-9f38-779f2cd66879",
    "2e3a4c9c-ff01-4a28-bfcf-ce9b7633a39d",  # no inactivity should be removed
    "3cf49c01-0499-4bad-9167-67691711204a",  # no inactivity should be removed PAS LA??
    "3d0f965c-9d72-43d1-9369-1ea3acf963cc",  # PAS LA ???
    "4b269cc2-8f0c-4816-adbf-10c0069b8833",
    "4bc51b90-bfce-4231-85e1-5de3b4bc0745",
    "4fc3c295-857f-4920-8fa5-f21bfdc7ab4f",
]  # bit of inactivity in the middle]

list_measurement_id = [
    "2d852742-10a9-4c56-9f38-779f2cd66879",
    "4fc3c295-857f-4920-8fa5-f21bfdc7ab4f",
    "db2e053a-0fb8-4206-891a-6f079fb14e3a",
]

# Filter df_train_label according to the measurement_id we are most interested in
df_train_label = interesting_patients(
    df_train_label=df_train_label, list_measurement_id=list_measurement_id
)

# Display filtered df_train_label
display(df_train_label)

# path_no_inactivity_data = remove_inactivity_pct_change(df_train_label)

# Plot the accelerometer data
plot_accelerometer(
    data_type=data_type, path_accelerometer_plots=path_save_accelerometer_plots
)

# %%
data_type = "cis"

# TODO: explain
path_train_data, df_train_label = define_data_type(data_type=data_type)

# list_measurement_id = ["5cf68c8e-0b7a-4b73-ad4f-015c7a20fb5a"]

# list_measurement_id = ["2e3a4c9c-ff01-4a28-bfcf-ce9b7633a39d"]

# list_measurement_id = [
#     "2d852742-10a9-4c56-9f38-779f2cd66879",
#     "4fc3c295-857f-4920-8fa5-f21bfdc7ab4f",
#     "db2e053a-0fb8-4206-891a-6f079fb14e3a",
# ]

# list_measurement_id = ["db2e053a-0fb8-4206-891a-6f079fb14e3a"]

# list_measurement_id=['2d852742-10a9-4c56-9f38-779f2cd66879']
# list_measurement_id=['5cf68c8e-0b7a-4b73-ad4f-015c7a20fb5a',
#                      'cc7b822c-e310-46f0-a8ea-98c95fdb67a1',
#                      '5163afe8-a6b0-4ea4-b2ba-9b4501dd5912',
#                     'db2e053a-0fb8-4206-891a-6f079fb14e3a',
#                     '2d852742-10a9-4c56-9f38-779f2cd66879',
#                     '2e3a4c9c-ff01-4a28-bfcf-ce9b7633a39d', # no inactivty should be removed
#                     '3cf49c01-0499-4bad-9167-67691711204a']

# df_train_label = interesting_patients(df_train_label=df_train_label, list_measurement_id=list_measurement_id)

remove_inactivity_highpass(
    df_train_label,
    energy_threshold=5,
    duration_threshold=3000,
    plot_frequency_response=False,
    mask_path='/home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.high_pass_mask/')

# remove_inactivity_mean_offset(df_train_label)
# path_no_inactivity_data = remove_inactivity_max(df_train_label)

# plot_accelerometer(data_type=data_type, path_accelerometer_plots=path_save_accelerometer_plots, path_inactivity=path_no_inactivity_data)
# Out:
# Working on  cc7b822c-e310-46f0-a8ea-98c95fdb67a1
# X_zeros.shape  (44940,)
# X_zeros.shape 2  (44940,)
# df_zeros.shape  (44940,)
# df_zeros.shape 2 (44940,)
# df_mask_highpass.shape  (44940, 1)
# -------------------------------------------------------------------
# NameError                         Traceback (most recent call last)
# <ipython-input-54-19372e25f5e6> in <module>
#      32     duration_threshold=3000,
#      33     plot_frequency_response=False,
# ---> 34     mask_path='/home/sjoshi/codes/python/BeatPD/data/BeatPD/cis-pd.training_data.high_pass_mask/')
#      35
#      36 # remove_inactivity_mean_offset(df_train_label)
#
# <ipython-input-53-0c0b02c531ed> in remove_inactivity_highpass(df_train_label, energy_threshold, duration_threshold, mask_path, plot_frequency_response, plot_accelerometer_after_removal)
#     153 #         )
#     154         print('df_mask_highpass.shape ', df_mask_highpass.shape)
# --> 155         stop()
#     156         # Plot the accelerometer with the removed sections
#     157         # The [0] is used to get a pandas.Series instead of a DataFrame
#
# NameError: name 'stop' is not defined

# %%
data_type = "cis"

# TODO: explain
path_train_data, df_train_label = define_data_type(data_type=data_type)

# list_measurement_id=['5cf68c8e-0b7a-4b73-ad4f-015c7a20fb5a',
#                      'cc7b822c-e310-46f0-a8ea-98c95fdb67a1',
#                      '5163afe8-a6b0-4ea4-b2ba-9b4501dd5912',
#                     'db2e053a-0fb8-4206-891a-6f079fb14e3a',
#                     '2d852742-10a9-4c56-9f38-779f2cd66879',
#                     '2e3a4c9c-ff01-4a28-bfcf-ce9b7633a39d', # no inactivity should be removed
#                     '3cf49c01-0499-4bad-9167-67691711204a',# no inactivty should be removed
#                     '3d0f965c-9d72-43d1-9369-1ea3acf963cc',
#                     '4b269cc2-8f0c-4816-adbf-10c0069b8833',
#                     '4bc51b90-bfce-4231-85e1-5de3b4bc0745',
#                     '4fc3c295-857f-4920-8fa5-f21bfdc7ab4f'] #bit of inactivity in the middle]

list_measurement_id = ["5cf68c8e-0b7a-4b73-ad4f-015c7a20fb5a"]

df_train_label = interesting_patients(
    df_train_label=df_train_label, list_measurement_id=list_measurement_id
)

path_no_inactivity_data = remove_inactivity_pct_change(df_train_label)

# Plot the accelerometer data
# plot_accelerometer(data_type=data_type, path_accelerometer_plots=path_save_accelerometer_plots, path_inactivity=path_no_inactivity_data)

# %% [markdown]
# ## Visualization: Occurences of each symptoms for each subject

# %%
# Compute the occurences of each symptoms for each patient
df_occurences, df_train_label_subject_id = compute_symptoms_occurences_dataframe(
    df_train_label=df_train_label
)

# Plot the graphs
plot_symptoms_occurences(
    df_occurences=df_occurences, df_train_label_subject_id=df_train_label_subject_id
)

# %% [markdown]
# ## KFold

# %%
def get_k_fold(df_train_label, n_splits=5, subject_id=None, data_real_subtype=""):
    """
    Function that returns a list of X dataframes (X is according to the number of n_splits chosen)

    The dataframes are the labels needed according to the split 

    Keyword Arguments:
    df_train_label: Dataframe containing the labels
    n_split: Optional. The number of folds. Default: 5
    subject_id: Optional. Specify a subject_id to get measurement_id only for that subject_id 
    data_real_subtype: Only for REAL-PD database
    """
    kf = KFold(n_splits)

    # Building the dataframe to split
    X = []

    # if we want the data split for one specific subject_id
    if subject_id:
        df_train_label_subject_id = df_train_label.groupby("subject_id")
        X = df_train_label_subject_id.get_group(subject_id)

    # if we want to have all a split for all data no matter the subject_id
    # NOTE: I didn't make sure to have one subject_id represented in both train/test
    else:
        for idx in df_train_label.index:
            X.append([df_train_label["measurement_id"][idx]])
        X = pd.DataFrame(X)

    kf.get_n_splits(X)

    # Building lists of df_train_label because we have by default 5 splits,
    # so the lists will contain 5 DataFrames with different split indices required
    list_df_train_label = list()
    list_df_test_label = list()
    split_idx = 0
    for train_index, test_index in kf.split(X):
        df_train_label = X.iloc[train_index]
        df_test_label = X.iloc[test_index]

        list_df_train_label.append(df_train_label)
        list_df_test_label.append(df_test_label)

        # name of the file according to its database and type
        path_save_k_fold_dataframes = (
            data_dir + data_type + "-pd.training_data.k_fold/" + data_real_subtype + "/"
        )
        df_train_label.to_csv(
            path_save_k_fold_dataframes
            + str(subject_id)
            + "_train_kfold_"
            + str(split_idx)
            + ".csv",
            index=False,
            header=["measurement_id", "subject_id", "on_off", "dyskinesia", "tremor"],
        )
        df_test_label.to_csv(
            path_save_k_fold_dataframes
            + str(subject_id)
            + "_test_kfold_"
            + str(split_idx)
            + ".csv",
            index=False,
            header=["measurement_id", "subject_id", "on_off", "dyskinesia", "tremor"],
        )
        split_idx = split_idx + 1
    return list_df_train_label, list_df_test_label

# %% [markdown]
# ### Create the K-Fold files for the CIS database

# %%
# Define the data type as we have two databases
data_type = "cis"
path_train_data, df_train_label = define_data_type(data_type=data_type)
display(df_train_label)

# Group data by subject_id
df_train_label_subject_id = df_train_label.groupby("subject_id")

# Go through the subject_id and k-fold their data
# FIXME: get_k_fold could me renamed to just create the folds, save them, not return anything
for subject_id, value in df_train_label_subject_id:
    list_df_train_label, list_df_test_label = get_k_fold(
        df_train_label=df_train_label, n_splits=5, subject_id=subject_id
    )


#### Example on how to read data

# TODO
# Read data from folders

# The following is not a really good example, it would be better to have an example where we read the
# data from the folder they're saved at


# Iterate through the DataFrame in the list list_df_train_label_train
# for df_train_label in list_df_train_label_train:
#     # Go through the measurement_id for this df_train_label split to read the training data corresponding
#     for idx in df_train_label.index:
#         # Read the train data for this specific measurement_id
#         # TODO: Do we want to append all of this training data together?
#         df_train_data=pd.read_csv(path_train_data+df_train_label["measurement_id"][idx]+'.csv')
#         #display(df_train_label)

# %% [markdown]
# ### Read the K-Fold data

# %%
# TODO

# %% [markdown]
# ### Create the K-Fold Files for the REAL database

# %%
# To generate the files, you have to uncomment one data_real_subtype at a time and
# execute this cell 3 times for the 3 subtypes.

data_type = "real"
# data_real_subtype='smartphone_accelerometer'
data_real_subtype = "smartwatch_accelerometer"
# data_real_subtype='smartwatch_gyroscope'

path_train_data, df_train_label = define_data_type(data_type=data_type)

# Group data by subject_id
df_train_label_subject_id = df_train_label.groupby("subject_id")

# Go through the subject_id and k-fold their data
for subject_id, value in df_train_label_subject_id:
    list_df_train_label, list_df_test_label = get_k_fold(
        df_train_label=df_train_label,
        n_splits=5,
        subject_id=subject_id,
        data_real_subtype=data_real_subtype,
    )

# %% [markdown]
# # REAL-PD Database

# %% [markdown]
# This database, originally named "Parkinson@Home" is renamed to "Real-PD" for this challenge. The study was made over 2 weeks, with at home monitoring.
#
# The devices used are an android phone, a motorolla watch.
# - `smartwatch_accelerometer` and `smartwatch_gyroscope` : Motorolla Watch
# - `smartphone_accelerometer` : Android phone
#
# -> Question: so is the smartwatch & smartphone accelerometer should measure the same movements?
#
# The REAL-PD database has many missing values.
#
# The subject_id `hbv013` is the only one without missing data. Other patients all have at least one missing symptom (`diskenisia`, ) or two (`on/off and tremor`, `on_off and dyskinesia`, `dyskinesia and tremor`) missing.
#
# Measurements id with no data (`on_off`, `dyskinesia` and `tremor` are all missing):
# - `b50d1b0c-2cd1-45f8-9097-0742e5cbbcc8`
# - `b598c177-4e38-4ea8-8543-bd8f7e580f96`
# - `cf841bf8-0082-4ea3-999f-1f43e39a8dc6`
# - `b1e15f8a-109f-459b-ba87-46899240ee66`
# - `6f0e2580-56ec-4743-9356-d3e4d9a0aee5`
# - `773536f6-9b70-43d0-b099-5d167d74924a`
# - `54a0e841-ad45-4ba7-ac83-1785c5f7748b`
# - `cd9ed2e2-7e04-44c7-b041-7788f133c193`
# - `a6954a91-338b-4523-9e4a-5e69a8fac206`
#
# The 3 symptoms are reported as follows in this dataset:
# - `on_off = {0,1}`
#   - `Off` : 0 (medication is wearing off)
#   - `On` : 1 (medication is working)
#
# - `dyskinesia = {0,1,2}`
#   - Without dyskinesia: 0
#   - Non-troublesome dyskinesia: 1
#   - Severe dyskinesia: 2
#
# - `tremor = {0,1,2,3,4}`
# The description of the database mentions `tremor` is rated from 0 to 4 according to its severity, but from all the data, the maximum value of `tremor` recorded is 3.
#
# Data:
# - ancillary
# - clinical : UPDRS evaluation score
# - demographics : #TODO

# %%
data_type = "real"
# data_real_subtype='smartphone_accelerometer'
data_real_subtype = "smartwatch_accelerometer"
# data_real_subtype='smartwatch_gyroscope'

path_train_data, df_train_label = define_data_type(data_type=data_type)

# List of interesting measurement id we want to look at
list_measurement_id = [
    "5b4c7c81-659d-40ea-a1fd-59622074fd10",
    "ee053d95-c155-400d-ae42-fe24834ad4a9",
    "ce51ee31-8553-4321-9f83-8cd3dabe2f66",
    "e07708ff-7b8d-4070-af70-3aa81423ab5b",
    #'7d3f4b7a-167f-4a26-9062-94ce9d8794c1',
    "99af8d14-cd09-4107-9502-355378ba4e08",
    #'7d5ac31a-cb53-40f7-8188-0b13724ea55c',
    "9e43840b-dd89-498b-af1a-a62896a4d5d9",
    "e391f546-bf8a-46c7-a16c-95bc02f40629",
]

# Filter df_train_label according to the measurement_id we are most interested in
df_train_label = interesting_patients(
    df_train_label=df_train_label, list_measurement_id=list_measurement_id
)

# Display filtered df_train_label
# display(df_train_label)

###  Plot the accelerometer data
# Path example: /home/sjoshi/codes/python/BeatPD/code/accelerometer_plots/real/smartwatch_gyroscope/
path = path_save_accelerometer_plots + "/" + data_type + "/" + data_real_subtype + "/"
plot_accelerometer(data_type=data_type, path_accelerometer_plots=path)

# %%
# Compute the occurences of each symptoms for each patient
df_occurences, df_train_label_subject_id = compute_symptoms_occurences_dataframe(
    df_train_label=df_train_label
)

# %%
# Plot the graphs
plot_symptoms_occurences(
    df_occurences=df_occurences, df_train_label_subject_id=df_train_label_subject_id
)

# %% [markdown]
# # Comparing both databases

# %% [markdown]
# <style type="text/css">
# .tg  {border-collapse:collapse;border-spacing:0;}
# .tg td{font-family:Arial, sans-serif;font-size:14px;padding:10px 5px;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:black;}
# .tg th{font-family:Arial, sans-serif;font-size:14px;font-weight:normal;padding:10px 5px;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:black;}
# .tg .tg-c3ow{border-color:inherit;text-align:center;vertical-align:top}
# .tg .tg-0pky{border-color:inherit;text-align:left;vertical-align:top}
# </style>
# <table class="tg">
#   <tr>
#     <th class="tg-0pky"></th>
#     <th class="tg-0pky">CIS-PD</th>
#     <th class="tg-0pky">REAL-PD</th>
#   </tr>
#   <tr>
#     <td class="tg-0pky"># of subject_id training</td>
#     <td class="tg-c3ow">16</td>
#     <td class="tg-c3ow">12</td>
#   </tr>
#   <tr>
#     <td class="tg-0pky"># of female training</td>
#     <td class="tg-c3ow">5</td>
#     <td class="tg-c3ow">7</td>
#   </tr>
#   <tr>
#     <td class="tg-0pky"># of male training</td>
#     <td class="tg-c3ow">11</td>
#     <td class="tg-c3ow">5</td>
#   </tr>
#   <tr>
#     <td class="tg-0pky">Age average (std deviation)</td>
#     <td class="tg-c3ow">62.8125 (10.857)</td>
#     <td class="tg-c3ow">59.833 (5.828)</td>
#   </tr>
# </table>

# %%
# DataFrame for specified subject_id
# display(df_train_label_subject_id.get_group('hbv013'))

# print(display(df_train_label_subject_id.get_group('hbv013')['tremor'].value_counts()))

# Graphs for a specific subject_id the 3 symptoms
# df_train_label_subject_id.get_group('hbv014')['tremor'].value_counts().plot(kind='bar', title='tremor')
# df_train_label_subject_id.get_group('hbv014')['dyskinesia'].value_counts().plot(kind='bar', title='dys')
# df_train_label_subject_id.get_group('hbv014')['on_off'].value_counts().plot(kind='bar', title='on_off')

# %% [markdown]
# # Tests & Drafts, back-up space that's not important, just notes

# %%
20 * 60 / 59848

# %%
# Change the default option to display all row with display(DF)
# pd.set_option('display.max_rows', 1000)

# %% [markdown]
# ### Tried to do convolution instead of np.multiply and dot product to get the derivative

# %%
df2 = pd.DataFrame(
    np.array(
        [
            [0.2, 1, 5, 9],
            [0.4, 2, 6, 10],
            [0.6, 3, 7, 11],
            [0.8, 4, 8, 12],
            [1, 5, 9, 13],
            [1.2, 6, 10, 14],
            [1.4, 7, 11, 15],
            [1.6, 7, 11, 15],
            [1.8, 8, 12, 16],
            [2, 9, 13, 16],
        ]
    ),
    columns=["Timestamp", "X", "Y", "Z"],
)
display(df2)
m = np.linspace(-3, 3, num=2 * 3 + 1)
display(m)

np.convolve(df2.loc[0:6, "X"], m)

# %% [markdown]
# ### How to filter a DataFrame

# %%
# Analysis of the data to find edge cases


# Create variable with TRUE if nationality is USA
dys = df_train_label["dyskinesia"] > 1

# Create variable with TRUE if age is greater than 50
tre = df_train_label["on_off"] > 0

# Select all cases where nationality is USA and age is greater than 50
df_train_label[dys & tre]

# %% [markdown]
# ### Playing around with pct_change function to try and remove_silence

# %%
# df_pct_change = df_train_data.iloc[:,-3:].pct_change(periods=5)
# #df_pct_change = df_train_data['X'].pct_change(periods=5)
# df_pct_change.columns = ['X', 'Y','Z']
# print('pct_change measurement id : ', df_train_label["measurement_id"][idx])
# display(df_pct_change)
# df_pct_change = df_pct_change[df_pct_change > 0.01]

cars = {
    "Brand": [
        "Honda Civic",
        "Toyota Corolla",
        "Ford Focus",
        "Audi A4",
        "Toyota Corolla",
        "Ford Focus",
        "Audi A4",
    ],
    "Price": [1, 1, 2, 3, 4, 5, 6],
    "Price2": [2, 3, 4, 5, 6, 7, 8],
}

df = pd.DataFrame(cars, columns=["Brand", "Price", "Price2"])
display(df)

display(df.iloc[:, -2:])

display(df.iloc[:, -2:].pct_change(periods=1))

df = df.iloc[:, -2:].pct_change(periods=1, fill_method="ffill")

df_pct_change = df[(df["Price"] > 0.25) & (df["Price2"] > 0.3)]
print("------------")
display(df_pct_change)
print("------------")
# display(df['Price'].pct_change(periods=1))

# display(df['Price','Price2'].pct_change(periods=2))

display(df["Price"].pct_change(periods=5))

# %%
cars = {  #'Brand': ['Honda Civic','Toyota Corolla','Ford Focus','Audi A4','Toyota Corolla','Ford Focus','Audi A4'],
    "Price": [1, 1, 2, 3, -10, 5, 6],
    "Price2": [2, 3, 4, 5, 6, 7, 8],
}

df = pd.DataFrame(cars, columns=["Brand", "Price", "Price2"])
display(df)

display(df.abs().max())

display((df.abs().max() * 5) / 100)

# %%
def remove_inactivity_max(df_train_label):
    last_filtered_value = pd.Series(np.zeros(3), index=["X", "Y", "Z"])
    filtered_value = pd.Series(np.zeros(3), index=["X", "Y", "Z"])
    display(last_filtered_value)
    for idx in df_train_label.index:
        df_allo = []
        df_train_data = pd.read_csv(
            path_train_data + df_train_label["measurement_id"][idx] + ".csv"
        )

        # Get the absolute max value for X, Y, Z
        max_values = df_train_data.iloc[:, -3:].abs().max()

        # Compute what is 5% of that max
        thresold_energy = 5
        df_treshold = (max_values * thresold_energy) / 100

        # display(df_train_data)
        # Candidates are the frames where X, Y, Z are below that treshold (5% of the max)
        #         df_candidates = df_train_data[(df_train_data.X.abs() <= df_treshold.X) &
        #                                      (df_train_data.Y.abs() <= df_treshold.Y) &
        #                                      (df_train_data.Z.abs() <= df_treshold.Z)]
        # display(df_candidates)
        for idx2 in df_train_data.index:
            # print('df_train_data[idx2]')
            # display(df_train_data.iloc[idx2,-3:])
            last_filtered_value = filtered_value
            filtered_value = last_filtered_value + 0.004 * (
                df_train_data.iloc[idx2, -3:] - last_filtered_value
            )
            y = pd.DataFrame(columns=["Timestamp"])
            y = pd.concat(
                [y, pd.DataFrame([df_train_data.iloc[idx2, 0]], columns=["Timestamp"])],
                ignore_index=True,
            )
            #             print('display y :')
            #             display(y)
            #             print('end display y')

            #             print('display filtered value')
            #             display(pd.DataFrame(filtered_value).transpose())
            #             print('end display filtered value')
            df_allo.append(
                pd.concat([y, pd.DataFrame(filtered_value).transpose()], axis=1)
            )
        #             print('display df_allo')
        #             display(df_allo)

        # FIXME : change the name df_allo
        df_allo = pd.DataFrame(df_allo, columns=("Timestamp", "X", "Y", "Z"))

        df_allo.plot(x="Timestamp", legend=True, subplots=True, title="allo")
        stop()


#         v_candidate_x = pd.DataFrame({'Candidate':list(0)})
#         v_candidate_x = np.where(df_train_data.X.abs() <= df_treshold.X, 1, 0)

# %%
# This didn't work because it's using pct_change between X coordinates where coincidences happens


def remove_inactivity_pct_change(df_train_label, data_real_subtype=""):
    """
    Save .csv files with silence (inactivity) removed 

    Path used: 
    # cis-pd.training_data.no_silence/
    # real-pd.training_data.no_silence/smartphone_accelerometer/
    # real-pd.training_data.no_silence/smartwatch_accelerometer/
    # real-pd.training_data.no_silence/smartwatch_gyroscope/
    # data_type = {'cis', 'real'}

    Arguments:
    df_train_label: Dataframe with training labels

    data_real_subtype: Optional. If data_type is real, data_real_subtype needs to be provided
        data_real_subtype={smartphone_accelerometer , smartwatch_accelerometer , smartwatch_gyroscope}

    Returns: 
    path_no_inactivity_data: Return the path where the files are saved because it is needed
                          if we want to plot the accelerometer, for example
    """
    count = 0
    for idx in df_train_label.index:
        df_train_data = pd.read_csv(
            path_train_data + df_train_label["measurement_id"][idx] + ".csv"
        )
        # print('measurement id : ', df_train_label["measurement_id"][idx])
        # display(df_train_data)
        cols_to_norm = ["x", "y", "z"] if data_type == "real" else ["X", "Y", "Z"]
        df_train_data[cols_to_norm] = df_train_data[cols_to_norm].apply(
            lambda x: (x - x.min()) / (x.max() - x.min())
        )
        periods = 300
        df_pct_change = df_train_data.iloc[:, -3:].pct_change(periods=periods)

        df_pct_change.columns = ["X", "Y", "Z"]
        # print('pct_change measurement id : ', df_train_label["measurement_id"][idx])
        # display(df_pct_change)

        # Apply the treshold to the DataFrame with an AND condition, so all axis must have at least 1% of change
        # between the periods
        # pd.options.display.max_rows = 1000
        print("----------before filter--------")
        display(df_pct_change.abs())

        print("WHAT IS DETECTED AS INACTIVITY")
        display(
            df_pct_change[
                (df_pct_change.X.abs() < 0.0002)
                | (df_pct_change.Y.abs() < 0.0002)
                | (df_pct_change.Z.abs() < 0.0002)
            ]
        )
        print("END OF WHAT IS DETECTED AS INACTIVITY")

        df_pct_change = df_pct_change[
            (df_pct_change.X.abs() >= 0.0002)
            & (df_pct_change.Y.abs() >= 0.0002)
            & (df_pct_change.Z.abs() >= 0.0002)
        ]
        print("----------after filter--------")
        display(df_pct_change)

        filter_df = df_train_data[
            df_train_data.index.isin(df_pct_change.index.to_list())
        ]

        # Counts the number of time where we had to remove inactivity from a dataframe to know how often
        # the inactivity zones appear.
        print("len(filter_df)+periods ", str(len(filter_df) + periods))
        print("len(df_train_data) ", str(len(df_train_data)))
        if len(filter_df) + periods != len(df_train_data):
            count = count + 1

        # To provide the name of the header for the Dataframe, we get the name of the x axis as it depends
        # on the data_type and then we insert it at the first position before the X,Y,Z axis
        x_axis_data_type = "t" if data_type == "real" else "Timestamp"
        cols_to_norm.insert(0, x_axis_data_type)

        # filter_df.plot(x='Timestamp',legend=True, subplots=True,title='allo')

        # Save the dataframe in a file with the measurement_id as the name of the file
        path_no_inactivity_data = (
            data_dir
            + data_type
            + "-pd.training_data.no_silence/"
            + data_real_subtype
            + "/"
        )
        filter_df.to_csv(
            path_no_inactivity_data + df_train_label["measurement_id"][idx] + ".csv",
            index=False,
            header=cols_to_norm,
        )
    print(
        "Inactivity zones were detected ",
        str(count),
        " times out of ",
        str(len(df_train_label.index)),
    )
    return path_no_inactivity_data

# %%
# df_zeros = pd.DataFrame([False,True,False,False,False,True,False]).astype(int)

df_zeros = np.array([0, 0, 0, 1, 0, 1, 1, 1, 1], dtype=bool)

display(df_zeros.astype(int))
count = 0
duration_threshold = 2
indices_list = []  # List of tuples
howmany = 0
for i in range(0, len(df_zeros)):
    if df_zeros[i] == 1:
        count = count + 1
        print("1 à lindex", i)
    else:
        if count >= duration_threshold:
            print("threshold atteint start ", start, " end at ", end)
            start = i - count
            end = i - 1
            indices_list.append((start, end))
            howmany = howmany + 1
            count = 0
        # if it doesn't reach the threshold, we change the 1 for 0 because we don't want to remove those
        elif count >= 1:
            print("Effacer les 1 de ", start, " a ", end)
            df_zeros[i - count : i] = [0] * (end - start)
            count = 0

display(df_zeros.astype(int))
